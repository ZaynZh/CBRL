# %%
import os
import random
import time
from dataclasses import dataclass

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tyro
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter

from goal_task import GoalTask

@dataclass
class Args:
    exp_name: str = 'MoA_ESN'
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "MoA_ESN_wandb"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""
    save_model: bool = False
    """whether to save model into the `runs/{run_name}` folder"""
    upload_model: bool = False
    """whether to upload the saved model to huggingface"""
    hf_entity: str = ""
    """the user or org name of the model repository from the Hugging Face Hub"""

    # Algorithm specific arguments
    env_id: str = "GoalTask"
    """the id of the environment"""
    total_timesteps: int = 40000
    """total timesteps of the experiments"""
    learning_rate: float = 3e-4
    """the learning rate of the optimizer"""
    buffer_size: int = 64
    """the replay memory buffer size"""
    gamma: float = 0.95
    """the discount factor gamma"""
    tau: float = 0.05
    """target smoothing coefficient (default: 0.005)"""
    batch_size: int = 64
    """the batch size of sample from the reply memory"""
    policy_noise: float = 0.2
    """the scale of policy noise"""
    exploration_noise: float = 0.1
    """the scale of exploration noise"""
    learning_starts: int = 0
    """timestep to start learning"""
    policy_frequency: int = 2
    """the frequency of training policy (delayed)"""
    noise_clip: float = 0.5
    """noise clip parameter of the Target Policy Smoothing Regularization"""


def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = GoalTask()
        env.action_space.seed(seed)
        return env

    return thunk


# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod() + np.prod(env.action_space.shape), 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, x, a):
        x = torch.cat([x, a], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class Actor(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod(), 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc_mu = nn.Linear(32, np.prod(env.action_space.shape))
        # action rescaling
        self.register_buffer(
            "action_scale", torch.tensor((env.action_space.high - env.action_space.low) / 2.0, dtype=torch.float32)
        )
        self.register_buffer(
            "action_bias", torch.tensor((env.action_space.high + env.action_space.low) / 2.0, dtype=torch.float32)
        )

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc_mu(x))
        return x * self.action_scale + self.action_bias

# %%
import stable_baselines3 as sb3

if sb3.__version__ < "2.0":
    raise ValueError(
            """Ongoing migration: run the following command to install the new dependencies:
poetry run pip install "stable_baselines3==2.0.0a1"
"""
        )

args = Args()
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

# %%
# env setup
envs = make_env(args.env_id, args.seed, 0, args.capture_video, run_name)()


actor = Actor(envs).to(device)
qf1 = QNetwork(envs).to(device)
qf2 = QNetwork(envs).to(device)
qf1_target = QNetwork(envs).to(device)
qf2_target = QNetwork(envs).to(device)
target_actor = Actor(envs).to(device)
target_actor.load_state_dict(actor.state_dict())
qf1_target.load_state_dict(qf1.state_dict())
qf2_target.load_state_dict(qf2.state_dict())
q_optimizer = optim.Adam(list(qf1.parameters()) + list(qf2.parameters()), lr=args.learning_rate)
actor_optimizer = optim.Adam(list(actor.parameters()), lr=args.learning_rate)

envs.observation_space.dtype = np.float32
rb = ReplayBuffer(
    args.buffer_size,
    envs.observation_space,
    envs.action_space,
    device,
    handle_timeout_termination=False,
)
start_time = time.time()

# %% [markdown]
# ### TRAIN

# %%
# TRY NOT TO MODIFY: start the game
obs, _ = envs.reset(seed=args.seed)
for global_step in range(args.total_timesteps):
    # ALGO LOGIC: put action logic here
    if global_step < args.learning_starts:
        actions = envs.action_space.sample()
    else:
        with torch.no_grad():
            actions = actor(torch.Tensor(obs).to(device))
            actions += torch.normal(0, actor.action_scale * args.exploration_noise)
            actions = actions.cpu().numpy().clip(envs.action_space.low, envs.action_space.high)

    # TRY NOT TO MODIFY: execute the game and log data.
    next_obs, rewards, terminations, truncations, infos = envs.step(actions)

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    if "final_info" in infos or terminations:
        print(f"global_step={global_step}, episodic_return={infos['episode']['r']}")
        writer.add_scalar("charts/episodic_return", infos["episode"]["r"], global_step)
        writer.add_scalar("charts/episodic_length", infos["episode"]["l"], global_step)     

    # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
    real_next_obs = next_obs.copy()
    if truncations:
        real_next_obs = infos["final_observation"]
    rb.add(obs, real_next_obs, actions, rewards, terminations, infos)

    # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
    obs = next_obs

    # ALGO LOGIC: training.
    if global_step > args.learning_starts:
        data = rb.sample(args.batch_size)
        with torch.no_grad():
            clipped_noise = (torch.randn_like(data.actions, device=device) * args.policy_noise).clamp(
                -args.noise_clip, args.noise_clip
            ) * target_actor.action_scale

            next_state_actions = (target_actor(data.next_observations) + clipped_noise).clamp(
                envs.action_space.low[0], envs.action_space.high[0]
            )
            qf1_next_target = qf1_target(data.next_observations, next_state_actions)
            qf2_next_target = qf2_target(data.next_observations, next_state_actions)
            min_qf_next_target = torch.min(qf1_next_target, qf2_next_target)
            next_q_value = data.rewards.flatten() + (1 - data.dones.flatten()) * args.gamma * (min_qf_next_target).view(-1)

        qf1_a_values = qf1(data.observations, data.actions).view(-1)
        qf2_a_values = qf2(data.observations, data.actions).view(-1)
        qf1_loss = F.mse_loss(qf1_a_values, next_q_value)
        qf2_loss = F.mse_loss(qf2_a_values, next_q_value)
        qf_loss = qf1_loss + qf2_loss

        # optimize the model
        q_optimizer.zero_grad()
        qf_loss.backward()
        q_optimizer.step()

        if global_step % args.policy_frequency == 0:
            actor_loss = -qf1(data.observations, actor(data.observations)).mean()
            actor_optimizer.zero_grad()
            actor_loss.backward()
            actor_optimizer.step()

            # update the target network
            for param, target_param in zip(actor.parameters(), target_actor.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
            for param, target_param in zip(qf1.parameters(), qf1_target.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
            for param, target_param in zip(qf2.parameters(), qf2_target.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)

        if global_step % 100 == 0:
            writer.add_scalar("losses/qf1_values", qf1_a_values.mean().item(), global_step)
            writer.add_scalar("losses/qf2_values", qf2_a_values.mean().item(), global_step)
            writer.add_scalar("losses/qf1_loss", qf1_loss.item(), global_step)
            writer.add_scalar("losses/qf2_loss", qf2_loss.item(), global_step)
            writer.add_scalar("losses/qf_loss", qf_loss.item() / 2.0, global_step)
            writer.add_scalar("losses/actor_loss", actor_loss.item(), global_step)
# Out:
# global_step=199, episodic_return=-1.6400000000000012
# global_step=399, episodic_return=-1.9200000000000015
# global_step=599, episodic_return=-1.9800000000000015
# global_step=799, episodic_return=-1.9600000000000015
# global_step=999, episodic_return=-1.9600000000000015
# global_step=1039, episodic_return=1
# global_step=1239, episodic_return=-1.9600000000000015
# global_step=1439, episodic_return=-1.9400000000000015
# global_step=1639, episodic_return=-1.9800000000000015
# global_step=1839, episodic_return=-1.9800000000000015
# global_step=2039, episodic_return=-1.9700000000000015
# global_step=2073, episodic_return=1
# global_step=2273, episodic_return=-0.25000000000000006
# global_step=2473, episodic_return=-1.9800000000000015
# global_step=2673, episodic_return=-1.9800000000000015
# global_step=2873, episodic_return=-1.7700000000000014
# global_step=3073, episodic_return=-1.9900000000000015
# global_step=3273, episodic_return=-1.6700000000000013
# global_step=3473, episodic_return=-0.02
# global_step=3673, episodic_return=-1.360000000000001
# global_step=3694, episodic_return=1
# global_step=3894, episodic_return=-1.2000000000000008
# global_step=4094, episodic_return=-0.11999999999999998
# global_step=4294, episodic_return=-1.450000000000001
# global_step=4494, episodic_return=-1.9900000000000015
# global_step=4504, episodic_return=1
# global_step=4704, episodic_return=-1.9800000000000015
# global_step=4904, episodic_return=-2.0000000000000013
# global_step=5104, episodic_return=-1.9800000000000015
# global_step=5112, episodic_return=1
# global_step=5312, episodic_return=-1.9800000000000015
# global_step=5321, episodic_return=1
# global_step=5521, episodic_return=-2.0000000000000013
# global_step=5721, episodic_return=-1.9800000000000015
# global_step=5921, episodic_return=-1.9800000000000015
# global_step=5930, episodic_return=1
# global_step=6130, episodic_return=-1.9900000000000015
# global_step=6330, episodic_return=-1.8900000000000015
# global_step=6339, episodic_return=1
# global_step=6539, episodic_return=-2.0000000000000013
# global_step=6739, episodic_return=-2.0000000000000013
# global_step=6939, episodic_return=-1.9700000000000015
# global_step=6947, episodic_return=1
# global_step=7147, episodic_return=-1.9800000000000015
# global_step=7347, episodic_return=-1.9900000000000015
# global_step=7547, episodic_return=-1.9800000000000015
# global_step=7747, episodic_return=-2.0000000000000013
# global_step=7947, episodic_return=-1.9900000000000015
# global_step=8147, episodic_return=-1.9900000000000015
# global_step=8347, episodic_return=-1.9800000000000015
# global_step=8547, episodic_return=-1.9900000000000015
# global_step=8747, episodic_return=-1.9800000000000015
# global_step=8947, episodic_return=-1.9800000000000015
# global_step=9147, episodic_return=-1.9800000000000015
# global_step=9347, episodic_return=-1.9700000000000015
# global_step=9547, episodic_return=-1.9900000000000015
# global_step=9747, episodic_return=-1.9900000000000015
# global_step=9755, episodic_return=1
# global_step=9762, episodic_return=1
# global_step=9962, episodic_return=-1.9900000000000015
# global_step=10162, episodic_return=-1.9800000000000015
# global_step=10362, episodic_return=-1.9900000000000015
# global_step=10562, episodic_return=-1.9900000000000015
# global_step=10762, episodic_return=-1.9900000000000015
# global_step=10962, episodic_return=-1.9900000000000015
# global_step=11162, episodic_return=-1.9700000000000015
# global_step=11362, episodic_return=-1.9800000000000015
# global_step=11562, episodic_return=-1.8200000000000014
# global_step=11762, episodic_return=-1.9700000000000015
# global_step=11962, episodic_return=-1.9800000000000015
# global_step=12162, episodic_return=-1.8200000000000014
# global_step=12362, episodic_return=-1.9700000000000015
# global_step=12562, episodic_return=-1.8100000000000014
# global_step=12762, episodic_return=-2.0000000000000013
# global_step=12962, episodic_return=-1.8100000000000014
# global_step=13162, episodic_return=-1.9800000000000015
# global_step=13362, episodic_return=-2.0000000000000013
# global_step=13562, episodic_return=-1.9900000000000015
# global_step=13762, episodic_return=-1.8100000000000014
# global_step=13962, episodic_return=-1.8000000000000014
# global_step=14162, episodic_return=-1.7800000000000014
# global_step=14362, episodic_return=-1.8000000000000014
# global_step=14562, episodic_return=-1.7200000000000013
# global_step=14762, episodic_return=-1.9900000000000015
# global_step=14962, episodic_return=-1.7900000000000014
# global_step=15162, episodic_return=-1.7900000000000014
# global_step=15362, episodic_return=-1.9500000000000015
# global_step=15562, episodic_return=-1.9200000000000015
# global_step=15762, episodic_return=-1.8900000000000015
# global_step=15962, episodic_return=-1.8500000000000014
# global_step=16162, episodic_return=-1.7700000000000014
# global_step=16362, episodic_return=-1.7700000000000014
# global_step=16562, episodic_return=-1.9800000000000015
# global_step=16762, episodic_return=-1.7600000000000013
# global_step=16962, episodic_return=-1.7700000000000014
# global_step=17162, episodic_return=-1.6500000000000012
# global_step=17177, episodic_return=1
# global_step=17377, episodic_return=-1.7900000000000014
# global_step=17577, episodic_return=-2.0000000000000013
# global_step=17777, episodic_return=-1.9800000000000015
# global_step=17977, episodic_return=-1.8700000000000014
# global_step=17988, episodic_return=1
# global_step=18001, episodic_return=1
# global_step=18201, episodic_return=-1.5500000000000012
# global_step=18210, episodic_return=1
# global_step=18410, episodic_return=-0.8800000000000006
# global_step=18426, episodic_return=1
# global_step=18626, episodic_return=-0.7300000000000004
# global_step=18636, episodic_return=1
# global_step=18836, episodic_return=-0.9600000000000006
# global_step=19036, episodic_return=-1.1100000000000008
# global_step=19236, episodic_return=1
# global_step=19257, episodic_return=1
# global_step=19387, episodic_return=1
# global_step=19398, episodic_return=1
# global_step=19448, episodic_return=1
# global_step=19461, episodic_return=1
# global_step=19472, episodic_return=1
# global_step=19511, episodic_return=1
# global_step=19525, episodic_return=1
# global_step=19538, episodic_return=1
# global_step=19636, episodic_return=0.9299999999999999
# global_step=19679, episodic_return=0.99
# global_step=19689, episodic_return=1
# global_step=19698, episodic_return=1
# global_step=19830, episodic_return=0.9299999999999999
# global_step=19845, episodic_return=1
# global_step=19872, episodic_return=1
# global_step=19884, episodic_return=1
# global_step=19895, episodic_return=1
# global_step=19920, episodic_return=1
# global_step=20089, episodic_return=0.95
# global_step=20100, episodic_return=1
# global_step=20195, episodic_return=1
# global_step=20205, episodic_return=1
# global_step=20236, episodic_return=1
# global_step=20330, episodic_return=1
# global_step=20354, episodic_return=1
# global_step=20455, episodic_return=1
# global_step=20482, episodic_return=1
# global_step=20499, episodic_return=1
# global_step=20512, episodic_return=1
# global_step=20525, episodic_return=1
# global_step=20615, episodic_return=1
# global_step=20624, episodic_return=1
# global_step=20631, episodic_return=1
# global_step=20659, episodic_return=1
# global_step=20669, episodic_return=1
# global_step=20677, episodic_return=1
# global_step=20695, episodic_return=1
# global_step=20704, episodic_return=1
# global_step=20714, episodic_return=1
# global_step=20744, episodic_return=0.99
# global_step=20753, episodic_return=1
# global_step=20762, episodic_return=1
# global_step=20780, episodic_return=1
# global_step=20791, episodic_return=1
# global_step=20800, episodic_return=1
# global_step=20816, episodic_return=1
# global_step=20827, episodic_return=1
# global_step=20835, episodic_return=1
# global_step=20845, episodic_return=1
# global_step=20862, episodic_return=1
# global_step=20878, episodic_return=1
# global_step=20951, episodic_return=1
# global_step=20971, episodic_return=1
# global_step=20991, episodic_return=1
# global_step=21012, episodic_return=1
# global_step=21029, episodic_return=1
# global_step=21041, episodic_return=1
# global_step=21050, episodic_return=1
# global_step=21062, episodic_return=1
# global_step=21074, episodic_return=1
# global_step=21085, episodic_return=1
# global_step=21125, episodic_return=1
# global_step=21139, episodic_return=1
# global_step=21158, episodic_return=1
# global_step=21169, episodic_return=1
# global_step=21179, episodic_return=1
# global_step=21187, episodic_return=1
# global_step=21197, episodic_return=1
# global_step=21217, episodic_return=1
# global_step=21235, episodic_return=1
# global_step=21254, episodic_return=0.99
# global_step=21264, episodic_return=1
# global_step=21279, episodic_return=1
# global_step=21288, episodic_return=1
# global_step=21389, episodic_return=1
# global_step=21401, episodic_return=1
# global_step=21417, episodic_return=1
# global_step=21426, episodic_return=1
# global_step=21441, episodic_return=1
# global_step=21450, episodic_return=1
# global_step=21495, episodic_return=1
# global_step=21503, episodic_return=1
# global_step=21510, episodic_return=1
# global_step=21518, episodic_return=1
# global_step=21532, episodic_return=1
# global_step=21547, episodic_return=1
# global_step=21556, episodic_return=1
# global_step=21566, episodic_return=1
# global_step=21575, episodic_return=1
# global_step=21585, episodic_return=1
# global_step=21593, episodic_return=1
# global_step=21601, episodic_return=1
# global_step=21614, episodic_return=1
# global_step=21622, episodic_return=1
# global_step=21639, episodic_return=1
# global_step=21839, episodic_return=-0.21000000000000005
# global_step=22039, episodic_return=-1.9300000000000015
# global_step=22046, episodic_return=1
# global_step=22246, episodic_return=-1.9100000000000015
# global_step=22422, episodic_return=0.7799999999999999
# global_step=22437, episodic_return=1
# global_step=22446, episodic_return=1
# global_step=22461, episodic_return=1
# global_step=22469, episodic_return=1
# global_step=22482, episodic_return=1
# global_step=22494, episodic_return=1
# global_step=22509, episodic_return=1
# global_step=22519, episodic_return=1
# global_step=22536, episodic_return=0.99
# global_step=22553, episodic_return=1
# global_step=22563, episodic_return=1
# global_step=22572, episodic_return=1
# global_step=22581, episodic_return=1
# global_step=22591, episodic_return=1
# global_step=22701, episodic_return=1
# global_step=22708, episodic_return=1
# global_step=22717, episodic_return=1
# global_step=22726, episodic_return=1
# global_step=22746, episodic_return=1
# global_step=22754, episodic_return=1
# global_step=22772, episodic_return=1
# global_step=22783, episodic_return=1
# global_step=22791, episodic_return=1
# global_step=22801, episodic_return=1
# global_step=22811, episodic_return=1
# global_step=22825, episodic_return=1
# global_step=22838, episodic_return=1
# global_step=22848, episodic_return=1
# global_step=22858, episodic_return=1
# global_step=22878, episodic_return=1
# global_step=22894, episodic_return=1
# global_step=22908, episodic_return=1
# global_step=22921, episodic_return=1
# global_step=22930, episodic_return=1
# global_step=22945, episodic_return=1
# global_step=22953, episodic_return=1
# global_step=22966, episodic_return=1
# global_step=22984, episodic_return=1
# global_step=23001, episodic_return=1
# global_step=23012, episodic_return=1
# global_step=23027, episodic_return=1
# global_step=23036, episodic_return=1
# global_step=23044, episodic_return=1
# global_step=23055, episodic_return=1
# global_step=23064, episodic_return=1
# global_step=23074, episodic_return=1
# global_step=23086, episodic_return=1
# global_step=23100, episodic_return=1
# global_step=23115, episodic_return=1
# global_step=23125, episodic_return=1
# global_step=23137, episodic_return=1
# global_step=23148, episodic_return=1
# global_step=23161, episodic_return=1
# global_step=23172, episodic_return=1
# global_step=23181, episodic_return=1
# global_step=23193, episodic_return=1
# global_step=23203, episodic_return=1
# global_step=23217, episodic_return=1
# global_step=23227, episodic_return=1
# global_step=23237, episodic_return=1
# global_step=23248, episodic_return=1
# global_step=23261, episodic_return=1
# global_step=23277, episodic_return=0.99
# global_step=23288, episodic_return=1
# global_step=23302, episodic_return=1
# global_step=23314, episodic_return=1
# global_step=23323, episodic_return=1
# global_step=23333, episodic_return=0.99
# global_step=23341, episodic_return=1
# global_step=23351, episodic_return=1
# global_step=23361, episodic_return=1
# global_step=23370, episodic_return=1
# global_step=23379, episodic_return=1
# global_step=23387, episodic_return=1
# global_step=23401, episodic_return=1
# global_step=23410, episodic_return=1
# global_step=23419, episodic_return=1
# global_step=23429, episodic_return=1
# global_step=23439, episodic_return=1
# global_step=23450, episodic_return=1
# global_step=23459, episodic_return=1
# global_step=23474, episodic_return=1
# global_step=23487, episodic_return=1
# global_step=23500, episodic_return=1
# global_step=23512, episodic_return=1
# global_step=23526, episodic_return=1
# global_step=23538, episodic_return=1
# global_step=23550, episodic_return=1
# global_step=23568, episodic_return=1
# global_step=23584, episodic_return=1
# global_step=23594, episodic_return=1
# global_step=23608, episodic_return=1
# global_step=23621, episodic_return=0.99
# global_step=23821, episodic_return=0
# global_step=24021, episodic_return=-1.6400000000000012
# global_step=24221, episodic_return=-1.9700000000000015
# global_step=24228, episodic_return=1
# global_step=24236, episodic_return=1
# global_step=24436, episodic_return=-2.0000000000000013
# global_step=24444, episodic_return=1
# global_step=24644, episodic_return=-1.9800000000000015
# global_step=24653, episodic_return=1
# global_step=24853, episodic_return=-0.5000000000000002
# global_step=24893, episodic_return=1
# global_step=24903, episodic_return=1
# global_step=24911, episodic_return=1
# global_step=24919, episodic_return=1
# global_step=24926, episodic_return=1
# global_step=24936, episodic_return=1
# global_step=24945, episodic_return=1
# global_step=24955, episodic_return=1
# global_step=24963, episodic_return=1
# global_step=24974, episodic_return=1
# global_step=24983, episodic_return=1
# global_step=24992, episodic_return=1
# global_step=25003, episodic_return=1
# global_step=25017, episodic_return=1
# global_step=25030, episodic_return=1
# global_step=25040, episodic_return=1
# global_step=25048, episodic_return=1
# global_step=25056, episodic_return=1
# global_step=25066, episodic_return=1
# global_step=25075, episodic_return=1
# global_step=25084, episodic_return=1
# global_step=25180, episodic_return=1
# global_step=25189, episodic_return=1
# global_step=25203, episodic_return=0.99
# global_step=25217, episodic_return=1
# global_step=25226, episodic_return=1
# global_step=25235, episodic_return=1
# global_step=25244, episodic_return=1
# global_step=25264, episodic_return=0.99
# global_step=25320, episodic_return=1
# global_step=25520, episodic_return=-0.01
# global_step=25698, episodic_return=1
# global_step=25712, episodic_return=1
# global_step=25721, episodic_return=1
# global_step=25729, episodic_return=1
# global_step=25743, episodic_return=1
# global_step=25754, episodic_return=1
# global_step=25763, episodic_return=1
# global_step=25771, episodic_return=1
# global_step=25783, episodic_return=1
# global_step=25791, episodic_return=1
# global_step=25799, episodic_return=1
# global_step=25811, episodic_return=0.99
# global_step=25823, episodic_return=1
# global_step=25832, episodic_return=1
# global_step=25845, episodic_return=1
# global_step=25855, episodic_return=1
# global_step=25871, episodic_return=1
# global_step=25884, episodic_return=1
# global_step=25892, episodic_return=1
# global_step=25903, episodic_return=1
# global_step=25914, episodic_return=1
# global_step=25922, episodic_return=1
# global_step=25933, episodic_return=1
# global_step=25942, episodic_return=1
# global_step=25954, episodic_return=1
# global_step=26062, episodic_return=1
# global_step=26078, episodic_return=1
# global_step=26090, episodic_return=1
# global_step=26100, episodic_return=1
# global_step=26110, episodic_return=1
# global_step=26119, episodic_return=1
# global_step=26130, episodic_return=0.99
# global_step=26138, episodic_return=1
# global_step=26147, episodic_return=1
# global_step=26156, episodic_return=1
# global_step=26166, episodic_return=1
# global_step=26175, episodic_return=1
# global_step=26185, episodic_return=1
# global_step=26194, episodic_return=1
# global_step=26202, episodic_return=1
# global_step=26212, episodic_return=1
# global_step=26222, episodic_return=1
# global_step=26231, episodic_return=1
# global_step=26240, episodic_return=1
# global_step=26250, episodic_return=1
# global_step=26258, episodic_return=1
# global_step=26267, episodic_return=1
# global_step=26277, episodic_return=0.99
# global_step=26285, episodic_return=1
# global_step=26292, episodic_return=1
# global_step=26303, episodic_return=1
# global_step=26313, episodic_return=1
# global_step=26321, episodic_return=1
# global_step=26330, episodic_return=1
# global_step=26338, episodic_return=1
# global_step=26348, episodic_return=1
# global_step=26359, episodic_return=1
# global_step=26368, episodic_return=1
# global_step=26377, episodic_return=1
# global_step=26387, episodic_return=1
# global_step=26397, episodic_return=1
# global_step=26406, episodic_return=1
# global_step=26416, episodic_return=1
# global_step=26424, episodic_return=1
# global_step=26433, episodic_return=1
# global_step=26442, episodic_return=1
# global_step=26451, episodic_return=1
# global_step=26460, episodic_return=1
# global_step=26470, episodic_return=0.99
# global_step=26481, episodic_return=1
# global_step=26491, episodic_return=1
# global_step=26501, episodic_return=0.99
# global_step=26511, episodic_return=1
# global_step=26521, episodic_return=1
# global_step=26529, episodic_return=1
# global_step=26538, episodic_return=1
# global_step=26547, episodic_return=1
# global_step=26557, episodic_return=1
# global_step=26565, episodic_return=1
# global_step=26575, episodic_return=1
# global_step=26584, episodic_return=1
# global_step=26593, episodic_return=1
# global_step=26602, episodic_return=1
# global_step=26611, episodic_return=1
# global_step=26620, episodic_return=1
# global_step=26628, episodic_return=1
# global_step=26638, episodic_return=0.99
# global_step=26647, episodic_return=1
# global_step=26657, episodic_return=1
# global_step=26666, episodic_return=1
# global_step=26675, episodic_return=1
# global_step=26684, episodic_return=1
# global_step=26695, episodic_return=1
# global_step=26704, episodic_return=1
# global_step=26713, episodic_return=1
# global_step=26721, episodic_return=1
# global_step=26730, episodic_return=1
# global_step=26739, episodic_return=1
# global_step=26748, episodic_return=1
# global_step=26757, episodic_return=1
# global_step=26766, episodic_return=1
# global_step=26773, episodic_return=1
# global_step=26782, episodic_return=1
# global_step=26792, episodic_return=1
# global_step=26800, episodic_return=1
# global_step=26809, episodic_return=1
# global_step=26819, episodic_return=1
# global_step=26828, episodic_return=1
# global_step=26836, episodic_return=1
# global_step=26847, episodic_return=0.99
# global_step=26858, episodic_return=1
# global_step=26869, episodic_return=0.99
# global_step=26877, episodic_return=1
# global_step=26886, episodic_return=1
# global_step=26896, episodic_return=1
# global_step=26904, episodic_return=1
# global_step=26913, episodic_return=1
# global_step=26921, episodic_return=1
# global_step=26931, episodic_return=1
# global_step=26939, episodic_return=1
# global_step=26947, episodic_return=1
# global_step=26956, episodic_return=1
# global_step=26965, episodic_return=1
# global_step=26974, episodic_return=1
# global_step=26982, episodic_return=1
# global_step=26991, episodic_return=1
# global_step=27000, episodic_return=1
# global_step=27010, episodic_return=0.99
# global_step=27020, episodic_return=1
# global_step=27029, episodic_return=1
# global_step=27038, episodic_return=1
# global_step=27046, episodic_return=1
# global_step=27056, episodic_return=1
# global_step=27066, episodic_return=1
# global_step=27074, episodic_return=1
# global_step=27082, episodic_return=1
# global_step=27091, episodic_return=1
# global_step=27100, episodic_return=1
# global_step=27108, episodic_return=1
# global_step=27117, episodic_return=1
# global_step=27124, episodic_return=1
# global_step=27133, episodic_return=1
# global_step=27139, episodic_return=1
# global_step=27149, episodic_return=1
# global_step=27159, episodic_return=0.99
# global_step=27168, episodic_return=1
# global_step=27176, episodic_return=1
# global_step=27187, episodic_return=1
# global_step=27197, episodic_return=0.99
# global_step=27207, episodic_return=1
# global_step=27215, episodic_return=1
# global_step=27223, episodic_return=1
# global_step=27233, episodic_return=1
# global_step=27243, episodic_return=0.99
# global_step=27252, episodic_return=1
# global_step=27261, episodic_return=1
# global_step=27269, episodic_return=1
# global_step=27278, episodic_return=1
# global_step=27287, episodic_return=1
# global_step=27295, episodic_return=1
# global_step=27305, episodic_return=1
# global_step=27315, episodic_return=1
# global_step=27323, episodic_return=1
# global_step=27333, episodic_return=1
# global_step=27343, episodic_return=1
# global_step=27352, episodic_return=1
# global_step=27362, episodic_return=0.99
# global_step=27372, episodic_return=1
# global_step=27382, episodic_return=1
# global_step=27390, episodic_return=1
# global_step=27398, episodic_return=1
# global_step=27407, episodic_return=1
# global_step=27417, episodic_return=1
# global_step=27424, episodic_return=1
# global_step=27433, episodic_return=1
# global_step=27442, episodic_return=1
# global_step=27451, episodic_return=1
# global_step=27460, episodic_return=1
# global_step=27472, episodic_return=0.99
# global_step=27479, episodic_return=1
# global_step=27488, episodic_return=1
# global_step=27499, episodic_return=1
# global_step=27508, episodic_return=1
# global_step=27516, episodic_return=1
# global_step=27527, episodic_return=1
# global_step=27535, episodic_return=1
# global_step=27543, episodic_return=1
# global_step=27553, episodic_return=1
# global_step=27563, episodic_return=0.99
# global_step=27571, episodic_return=1
# global_step=27580, episodic_return=1
# global_step=27589, episodic_return=1
# global_step=27597, episodic_return=1
# global_step=27604, episodic_return=1
# global_step=27613, episodic_return=1
# global_step=27621, episodic_return=1
# global_step=27630, episodic_return=1
# global_step=27638, episodic_return=1
# global_step=27647, episodic_return=1
# global_step=27656, episodic_return=1
# global_step=27665, episodic_return=1
# global_step=27675, episodic_return=0.99
# global_step=27685, episodic_return=1
# global_step=27694, episodic_return=1
# global_step=27702, episodic_return=1
# global_step=27711, episodic_return=1
# global_step=27720, episodic_return=1
# global_step=27730, episodic_return=1
# global_step=27739, episodic_return=1
# global_step=27747, episodic_return=1
# global_step=27757, episodic_return=1
# global_step=27766, episodic_return=1
# global_step=27773, episodic_return=1
# global_step=27782, episodic_return=1
# global_step=27792, episodic_return=1
# global_step=27800, episodic_return=1
# global_step=27808, episodic_return=1
# global_step=27817, episodic_return=1
# global_step=27826, episodic_return=1
# global_step=27835, episodic_return=1
# global_step=27843, episodic_return=1
# global_step=27852, episodic_return=1
# global_step=27861, episodic_return=1
# global_step=27869, episodic_return=1
# global_step=27878, episodic_return=1
# global_step=27886, episodic_return=1
# global_step=27893, episodic_return=1
# global_step=27927, episodic_return=1
# global_step=27934, episodic_return=1
# global_step=27944, episodic_return=1
# global_step=27954, episodic_return=1
# global_step=27964, episodic_return=1
# global_step=27974, episodic_return=1
# global_step=27984, episodic_return=1
# global_step=27993, episodic_return=1
# global_step=28001, episodic_return=1
# global_step=28009, episodic_return=1
# global_step=28019, episodic_return=1
# global_step=28026, episodic_return=1
# global_step=28035, episodic_return=1
# global_step=28042, episodic_return=1
# global_step=28052, episodic_return=1
# global_step=28061, episodic_return=1
# global_step=28071, episodic_return=1
# global_step=28080, episodic_return=1
# global_step=28089, episodic_return=1
# global_step=28098, episodic_return=1
# global_step=28108, episodic_return=1
# global_step=28116, episodic_return=1
# global_step=28124, episodic_return=1
# global_step=28134, episodic_return=0.99
# global_step=28142, episodic_return=1
# global_step=28152, episodic_return=1
# global_step=28160, episodic_return=1
# global_step=28168, episodic_return=1
# global_step=28177, episodic_return=1
# global_step=28187, episodic_return=1
# global_step=28196, episodic_return=1
# global_step=28205, episodic_return=1
# global_step=28214, episodic_return=1
# global_step=28223, episodic_return=1
# global_step=28230, episodic_return=1
# global_step=28239, episodic_return=1
# global_step=28246, episodic_return=1
# global_step=28256, episodic_return=1
# global_step=28264, episodic_return=1
# global_step=28273, episodic_return=1
# global_step=28281, episodic_return=1
# global_step=28290, episodic_return=1
# global_step=28299, episodic_return=1
# global_step=28308, episodic_return=1
# global_step=28316, episodic_return=1
# global_step=28323, episodic_return=1
# global_step=28330, episodic_return=1
# global_step=28340, episodic_return=1
# global_step=28348, episodic_return=1
# global_step=28359, episodic_return=1
# global_step=28367, episodic_return=1
# global_step=28377, episodic_return=1
# global_step=28386, episodic_return=1
# global_step=28395, episodic_return=1
# global_step=28406, episodic_return=0.99
# global_step=28415, episodic_return=1
# global_step=28424, episodic_return=1
# global_step=28432, episodic_return=1
# global_step=28441, episodic_return=1
# global_step=28451, episodic_return=1
# global_step=28460, episodic_return=1
# global_step=28468, episodic_return=1
# global_step=28477, episodic_return=1
# global_step=28486, episodic_return=1
# global_step=28495, episodic_return=1
# global_step=28503, episodic_return=1
# global_step=28513, episodic_return=1
# global_step=28522, episodic_return=1
# global_step=28531, episodic_return=1
# global_step=28541, episodic_return=1
# global_step=28549, episodic_return=1
# global_step=28559, episodic_return=0.99
# global_step=28568, episodic_return=1
# global_step=28578, episodic_return=1
# global_step=28586, episodic_return=1
# global_step=28595, episodic_return=1
# global_step=28605, episodic_return=0.99
# global_step=28614, episodic_return=1
# global_step=28624, episodic_return=1
# global_step=28632, episodic_return=1
# global_step=28642, episodic_return=1
# global_step=28652, episodic_return=1
# global_step=28661, episodic_return=1
# global_step=28670, episodic_return=1
# global_step=28679, episodic_return=1
# global_step=28687, episodic_return=1
# global_step=28697, episodic_return=0.99
# global_step=28707, episodic_return=1
# global_step=28716, episodic_return=1
# global_step=28723, episodic_return=1
# global_step=28731, episodic_return=1
# global_step=28741, episodic_return=1
# global_step=28749, episodic_return=1
# global_step=28758, episodic_return=1
# global_step=28767, episodic_return=1
# global_step=28776, episodic_return=1
# global_step=28785, episodic_return=1
# global_step=28793, episodic_return=1
# global_step=28801, episodic_return=1
# global_step=28811, episodic_return=1
# global_step=28820, episodic_return=1
# global_step=28828, episodic_return=1
# global_step=28837, episodic_return=1
# global_step=28844, episodic_return=1
# global_step=28853, episodic_return=1
# global_step=28862, episodic_return=1
# global_step=28872, episodic_return=0.99
# global_step=28881, episodic_return=1
# global_step=28890, episodic_return=1
# global_step=28898, episodic_return=1
# global_step=28906, episodic_return=1
# global_step=28914, episodic_return=1
# global_step=28922, episodic_return=1
# global_step=28930, episodic_return=1
# global_step=28939, episodic_return=1
# global_step=28947, episodic_return=1
# global_step=28955, episodic_return=1
# global_step=28964, episodic_return=1
# global_step=28972, episodic_return=1
# global_step=28981, episodic_return=1
# global_step=28990, episodic_return=1
# global_step=28998, episodic_return=1
# global_step=29006, episodic_return=1
# global_step=29014, episodic_return=1
# global_step=29024, episodic_return=1
# global_step=29032, episodic_return=1
# global_step=29042, episodic_return=1
# global_step=29052, episodic_return=0.99
# global_step=29060, episodic_return=1
# global_step=29069, episodic_return=1
# global_step=29079, episodic_return=0.99
# global_step=29087, episodic_return=1
# global_step=29094, episodic_return=1
# global_step=29104, episodic_return=0.99
# global_step=29113, episodic_return=1
# global_step=29123, episodic_return=0.99
# global_step=29131, episodic_return=1
# global_step=29138, episodic_return=1
# global_step=29145, episodic_return=1
# global_step=29153, episodic_return=1
# global_step=29162, episodic_return=1
# global_step=29172, episodic_return=1
# global_step=29180, episodic_return=1
# global_step=29190, episodic_return=1
# global_step=29199, episodic_return=1
# global_step=29208, episodic_return=1
# global_step=29216, episodic_return=1
# global_step=29225, episodic_return=1
# global_step=29235, episodic_return=0.99
# global_step=29244, episodic_return=1
# global_step=29252, episodic_return=1
# global_step=29261, episodic_return=1
# global_step=29270, episodic_return=1
# global_step=29279, episodic_return=1
# global_step=29286, episodic_return=1
# global_step=29294, episodic_return=1
# global_step=29303, episodic_return=1
# global_step=29312, episodic_return=1
# global_step=29320, episodic_return=1
# global_step=29328, episodic_return=1
# global_step=29337, episodic_return=1
# global_step=29345, episodic_return=1
# global_step=29355, episodic_return=0.99
# global_step=29363, episodic_return=1
# global_step=29372, episodic_return=1
# global_step=29381, episodic_return=1
# global_step=29387, episodic_return=1
# global_step=29396, episodic_return=1
# global_step=29404, episodic_return=1
# global_step=29412, episodic_return=1
# global_step=29420, episodic_return=1
# global_step=29429, episodic_return=1
# global_step=29438, episodic_return=1
# global_step=29447, episodic_return=1
# global_step=29455, episodic_return=1
# global_step=29465, episodic_return=1
# global_step=29473, episodic_return=1
# global_step=29482, episodic_return=1
# global_step=29491, episodic_return=1
# global_step=29501, episodic_return=1
# global_step=29509, episodic_return=1
# global_step=29516, episodic_return=1
# global_step=29524, episodic_return=1
# global_step=29533, episodic_return=1
# global_step=29541, episodic_return=1
# global_step=29551, episodic_return=0.99
# global_step=29560, episodic_return=1
# global_step=29569, episodic_return=1
# global_step=29576, episodic_return=1
# global_step=29586, episodic_return=1
# global_step=29597, episodic_return=0.99
# global_step=29604, episodic_return=1
# global_step=29613, episodic_return=1
# global_step=29623, episodic_return=0.99
# global_step=29632, episodic_return=1
# global_step=29641, episodic_return=1
# global_step=29649, episodic_return=1
# global_step=29656, episodic_return=1
# global_step=29664, episodic_return=1
# global_step=29674, episodic_return=1
# global_step=29684, episodic_return=1
# global_step=29691, episodic_return=1
# global_step=29698, episodic_return=1
# global_step=29706, episodic_return=1
# global_step=29714, episodic_return=1
# global_step=29724, episodic_return=1
# global_step=29733, episodic_return=1
# global_step=29742, episodic_return=1
# global_step=29750, episodic_return=1
# global_step=29758, episodic_return=1
# global_step=29768, episodic_return=1
# global_step=29776, episodic_return=1
# global_step=29783, episodic_return=1
# global_step=29790, episodic_return=1
# global_step=29799, episodic_return=1
# global_step=29809, episodic_return=0.99
# global_step=29819, episodic_return=1
# global_step=29828, episodic_return=1
# global_step=29836, episodic_return=1
# global_step=29846, episodic_return=0.99
# global_step=29854, episodic_return=1
# global_step=29863, episodic_return=1
# global_step=29872, episodic_return=1
# global_step=29880, episodic_return=1
# global_step=29889, episodic_return=1
# global_step=29899, episodic_return=0.99
# global_step=29906, episodic_return=1
# global_step=29915, episodic_return=1
# global_step=29923, episodic_return=1
# global_step=29933, episodic_return=1
# global_step=29941, episodic_return=1
# global_step=29951, episodic_return=0.99
# global_step=29959, episodic_return=1
# global_step=29968, episodic_return=1
# global_step=29977, episodic_return=1
# global_step=29986, episodic_return=1
# global_step=29996, episodic_return=1
# global_step=30005, episodic_return=1
# global_step=30013, episodic_return=1
# global_step=30022, episodic_return=1
# global_step=30031, episodic_return=1
# global_step=30040, episodic_return=1
# global_step=30048, episodic_return=1
# global_step=30056, episodic_return=1
# global_step=30066, episodic_return=0.99
# global_step=30076, episodic_return=0.99
# global_step=30085, episodic_return=1
# global_step=30093, episodic_return=1
# global_step=30101, episodic_return=1
# global_step=30109, episodic_return=1
# global_step=30117, episodic_return=1
# global_step=30126, episodic_return=1
# global_step=30135, episodic_return=1
# global_step=30144, episodic_return=1
# global_step=30153, episodic_return=1
# global_step=30162, episodic_return=1
# global_step=30172, episodic_return=1
# global_step=30182, episodic_return=1
# global_step=30191, episodic_return=1
# global_step=30201, episodic_return=0.99
# global_step=30210, episodic_return=1
# global_step=30218, episodic_return=1
# global_step=30228, episodic_return=1
# global_step=30238, episodic_return=1
# global_step=30246, episodic_return=1
# global_step=30253, episodic_return=1
# global_step=30263, episodic_return=0.99
# global_step=30274, episodic_return=0.99
# global_step=30282, episodic_return=1
# global_step=30292, episodic_return=0.99
# global_step=30301, episodic_return=1
# global_step=30308, episodic_return=1
# global_step=30317, episodic_return=1
# global_step=30326, episodic_return=1
# global_step=30335, episodic_return=1
# global_step=30345, episodic_return=1
# global_step=30353, episodic_return=1
# global_step=30362, episodic_return=1
# global_step=30372, episodic_return=0.99
# global_step=30380, episodic_return=1
# global_step=30388, episodic_return=1
# global_step=30398, episodic_return=1
# global_step=30407, episodic_return=1
# global_step=30415, episodic_return=1
# global_step=30423, episodic_return=1
# global_step=30433, episodic_return=0.99
# global_step=30443, episodic_return=0.99
# global_step=30453, episodic_return=0.99
# global_step=30461, episodic_return=1
# global_step=30470, episodic_return=1
# global_step=30477, episodic_return=1
# global_step=30487, episodic_return=0.99
# global_step=30496, episodic_return=1
# global_step=30503, episodic_return=1
# global_step=30511, episodic_return=1
# global_step=30520, episodic_return=1
# global_step=30530, episodic_return=1
# global_step=30538, episodic_return=1
# global_step=30548, episodic_return=1
# global_step=30557, episodic_return=1
# global_step=30567, episodic_return=1
# global_step=30576, episodic_return=1
# global_step=30583, episodic_return=1
# global_step=30593, episodic_return=1
# global_step=30601, episodic_return=1
# global_step=30608, episodic_return=1
# global_step=30618, episodic_return=0.99
# global_step=30627, episodic_return=1
# global_step=30636, episodic_return=1
# global_step=30643, episodic_return=1
# global_step=30651, episodic_return=1
# global_step=30659, episodic_return=1
# global_step=30669, episodic_return=0.99
# global_step=30678, episodic_return=1
# global_step=30685, episodic_return=1
# global_step=30695, episodic_return=0.99
# global_step=30704, episodic_return=1
# global_step=30713, episodic_return=1
# global_step=30721, episodic_return=1
# global_step=30730, episodic_return=1
# global_step=30739, episodic_return=1
# global_step=30748, episodic_return=1
# global_step=30755, episodic_return=1
# global_step=30765, episodic_return=1
# global_step=30773, episodic_return=1
# global_step=30780, episodic_return=1
# global_step=30789, episodic_return=1
# global_step=30798, episodic_return=1
# global_step=30806, episodic_return=1
# global_step=30815, episodic_return=1
# global_step=30823, episodic_return=1
# global_step=30833, episodic_return=0.99
# global_step=30842, episodic_return=1
# global_step=30851, episodic_return=1
# global_step=30861, episodic_return=0.99
# global_step=30870, episodic_return=1
# global_step=30878, episodic_return=1
# global_step=30887, episodic_return=1
# global_step=30894, episodic_return=1
# global_step=30903, episodic_return=1
# global_step=30913, episodic_return=0.99
# global_step=30922, episodic_return=1
# global_step=30930, episodic_return=1
# global_step=30940, episodic_return=0.99
# global_step=30948, episodic_return=1
# global_step=30958, episodic_return=1
# global_step=30967, episodic_return=1
# global_step=30974, episodic_return=1
# global_step=30984, episodic_return=1
# global_step=30992, episodic_return=1
# global_step=30999, episodic_return=1
# global_step=31008, episodic_return=1
# global_step=31016, episodic_return=1
# global_step=31024, episodic_return=1
# global_step=31032, episodic_return=1
# global_step=31041, episodic_return=1
# global_step=31050, episodic_return=1
# global_step=31059, episodic_return=1
# global_step=31066, episodic_return=1
# global_step=31075, episodic_return=1
# global_step=31084, episodic_return=1
# global_step=31091, episodic_return=1
# global_step=31101, episodic_return=0.99
# global_step=31109, episodic_return=1
# global_step=31119, episodic_return=0.99
# global_step=31127, episodic_return=1
# global_step=31135, episodic_return=1
# global_step=31145, episodic_return=0.99
# global_step=31154, episodic_return=1
# global_step=31163, episodic_return=1
# global_step=31171, episodic_return=1
# global_step=31181, episodic_return=1
# global_step=31191, episodic_return=1
# global_step=31197, episodic_return=1
# global_step=31205, episodic_return=1
# global_step=31214, episodic_return=1
# global_step=31223, episodic_return=1
# global_step=31232, episodic_return=1
# global_step=31239, episodic_return=1
# global_step=31247, episodic_return=1
# global_step=31255, episodic_return=1
# global_step=31263, episodic_return=1
# global_step=31271, episodic_return=1
# global_step=31279, episodic_return=1
# global_step=31287, episodic_return=1
# global_step=31295, episodic_return=1
# global_step=31304, episodic_return=1
# global_step=31312, episodic_return=1
# global_step=31320, episodic_return=1
# global_step=31330, episodic_return=0.99
# global_step=31336, episodic_return=1
# global_step=31345, episodic_return=1
# global_step=31355, episodic_return=0.99
# global_step=31364, episodic_return=1
# global_step=31373, episodic_return=1
# global_step=31381, episodic_return=1
# global_step=31387, episodic_return=1
# global_step=31397, episodic_return=0.99
# global_step=31405, episodic_return=1
# global_step=31413, episodic_return=1
# global_step=31422, episodic_return=1
# global_step=31432, episodic_return=0.99
# global_step=31442, episodic_return=1
# global_step=31451, episodic_return=1
# global_step=31461, episodic_return=1
# global_step=31471, episodic_return=1
# global_step=31479, episodic_return=1
# global_step=31488, episodic_return=1
# global_step=31497, episodic_return=1
# global_step=31505, episodic_return=1
# global_step=31513, episodic_return=1
# global_step=31521, episodic_return=1
# global_step=31529, episodic_return=1
# global_step=31536, episodic_return=1
# global_step=31546, episodic_return=1
# global_step=31554, episodic_return=1
# global_step=31564, episodic_return=1
# global_step=31572, episodic_return=1
# global_step=31581, episodic_return=1
# global_step=31590, episodic_return=1
# global_step=31600, episodic_return=1
# global_step=31609, episodic_return=1
# global_step=31618, episodic_return=1
# global_step=31627, episodic_return=1
# global_step=31636, episodic_return=1
# global_step=31646, episodic_return=1
# global_step=31655, episodic_return=1
# global_step=31664, episodic_return=1
# global_step=31672, episodic_return=1
# global_step=31681, episodic_return=1
# global_step=31690, episodic_return=1
# global_step=31699, episodic_return=1
# global_step=31709, episodic_return=0.99
# global_step=31717, episodic_return=1
# global_step=31726, episodic_return=1
# global_step=31734, episodic_return=1
# global_step=31743, episodic_return=1
# global_step=31752, episodic_return=1
# global_step=31762, episodic_return=1
# global_step=31770, episodic_return=1
# global_step=31777, episodic_return=1
# global_step=31787, episodic_return=1
# global_step=31795, episodic_return=1
# global_step=31804, episodic_return=1
# global_step=31811, episodic_return=1
# global_step=31820, episodic_return=1
# global_step=31829, episodic_return=1
# global_step=31838, episodic_return=1
# global_step=31846, episodic_return=1
# global_step=31855, episodic_return=1
# global_step=31865, episodic_return=0.99
# global_step=31873, episodic_return=1
# global_step=31883, episodic_return=1
# global_step=31892, episodic_return=1
# global_step=31901, episodic_return=1
# global_step=31910, episodic_return=1
# global_step=31919, episodic_return=1
# global_step=31927, episodic_return=1
# global_step=31935, episodic_return=1
# global_step=31942, episodic_return=1
# global_step=31949, episodic_return=1
# global_step=31958, episodic_return=1
# global_step=31966, episodic_return=1
# global_step=31974, episodic_return=1
# global_step=31983, episodic_return=1
# global_step=31992, episodic_return=1
# global_step=32000, episodic_return=1
# global_step=32010, episodic_return=0.99
# global_step=32019, episodic_return=1
# global_step=32028, episodic_return=1
# global_step=32036, episodic_return=1
# global_step=32044, episodic_return=1
# global_step=32053, episodic_return=1
# global_step=32063, episodic_return=1
# global_step=32073, episodic_return=0.99
# global_step=32083, episodic_return=1
# global_step=32093, episodic_return=1
# global_step=32102, episodic_return=1
# global_step=32111, episodic_return=1
# global_step=32120, episodic_return=1
# global_step=32128, episodic_return=1
# global_step=32139, episodic_return=1
# global_step=32147, episodic_return=1
# global_step=32155, episodic_return=1
# global_step=32201, episodic_return=0.99
# global_step=32211, episodic_return=1
# global_step=32221, episodic_return=1
# global_step=32229, episodic_return=1
# global_step=32238, episodic_return=1
# global_step=32247, episodic_return=1
# global_step=32255, episodic_return=1
# global_step=32263, episodic_return=1
# global_step=32272, episodic_return=1
# global_step=32281, episodic_return=1
# global_step=32289, episodic_return=1
# global_step=32298, episodic_return=1
# global_step=32305, episodic_return=1
# global_step=32314, episodic_return=1
# global_step=32323, episodic_return=1
# global_step=32333, episodic_return=1
# global_step=32343, episodic_return=1
# global_step=32351, episodic_return=1
# global_step=32361, episodic_return=0.99
# global_step=32370, episodic_return=1
# global_step=32378, episodic_return=1
# global_step=32387, episodic_return=1
# global_step=32396, episodic_return=1
# global_step=32404, episodic_return=1
# global_step=32413, episodic_return=1
# global_step=32423, episodic_return=1
# global_step=32431, episodic_return=1
# global_step=32440, episodic_return=1
# global_step=32451, episodic_return=0.99
# global_step=32462, episodic_return=0.99
# global_step=32472, episodic_return=1
# global_step=32672, episodic_return=0
# global_step=32680, episodic_return=1
# global_step=32880, episodic_return=-1.0000000000000007
# global_step=33080, episodic_return=-1.9900000000000015
# global_step=33280, episodic_return=-1.9500000000000015
# global_step=33287, episodic_return=1
# global_step=33487, episodic_return=-1.9800000000000015
# global_step=33687, episodic_return=-2.0000000000000013
# global_step=33887, episodic_return=-1.9800000000000015
# global_step=34087, episodic_return=-1.9900000000000015
# global_step=34287, episodic_return=-1.9900000000000015
# global_step=34294, episodic_return=1
# global_step=34494, episodic_return=-1.9800000000000015
# global_step=34694, episodic_return=-1.9800000000000015
# global_step=34894, episodic_return=-1.8900000000000015
# global_step=35094, episodic_return=-1.9800000000000015
# global_step=35294, episodic_return=-1.9900000000000015
# global_step=35302, episodic_return=1
# global_step=35502, episodic_return=-2.0000000000000013
# global_step=35702, episodic_return=-1.8300000000000014
# global_step=35902, episodic_return=-1.9800000000000015
# global_step=36102, episodic_return=-1.9800000000000015
# global_step=36110, episodic_return=1
# global_step=36310, episodic_return=-1.8200000000000014
# global_step=36510, episodic_return=-1.8200000000000014
# global_step=36710, episodic_return=-1.8200000000000014
# global_step=36910, episodic_return=-1.9900000000000015
# global_step=37110, episodic_return=-1.8000000000000014
# global_step=37310, episodic_return=-1.9900000000000015
# global_step=37510, episodic_return=-1.9900000000000015
# global_step=37710, episodic_return=-1.9900000000000015
# global_step=37910, episodic_return=-0.8700000000000006
# global_step=37918, episodic_return=1
# global_step=37927, episodic_return=1
# global_step=38127, episodic_return=-0.01
# global_step=38136, episodic_return=1
# global_step=38145, episodic_return=1
# global_step=38154, episodic_return=1
# global_step=38354, episodic_return=-0.01
# global_step=38363, episodic_return=1
# global_step=38371, episodic_return=1
# global_step=38571, episodic_return=0
# global_step=38771, episodic_return=0
# global_step=38971, episodic_return=0
# global_step=39171, episodic_return=-1.0500000000000007
# global_step=39371, episodic_return=-0.07
# global_step=39571, episodic_return=-0.7700000000000005
# global_step=39771, episodic_return=-1.9200000000000015
# global_step=39777, episodic_return=1
# global_step=39977, episodic_return=-1.9800000000000015
