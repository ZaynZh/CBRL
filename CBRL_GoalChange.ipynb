# %% [markdown]
# ### MODELS

# %%
import os
import random
import time
from dataclasses import dataclass
import pickle

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tyro
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter

from goal_task import GoalTask


@dataclass
class Args:
    exp_name: str = 'CBRL'
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "MoA_ESN_wandb"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""
    save_model: bool = False
    """whether to save model into the `runs/{run_name}` folder"""
    upload_model: bool = False
    """whether to upload the saved model to huggingface"""
    hf_entity: str = ""
    """the user or org name of the model repository from the Hugging Face Hub"""

    #Environment specific arguments
    goal_change = False
    test = False
    initial_positions = None

    # Algorithm specific arguments
    env_id: str = "GoalChange"
    """the id of the environment"""
    total_timesteps: int = 120000
    """total timesteps of the experiments"""
    learning_rate: float = 3e-4
    """the learning rate of the optimizer"""
    buffer_size: int = 64
    """the replay memory buffer size"""
    gamma: float = 0.95
    """the discount factor gamma"""
    tau: float = 0.05
    """target smoothing coefficient (default: 0.005)"""
    batch_size: int = 64
    """the batch size of sample from the reply memory"""
    policy_noise: float = 0
    """the scale of policy noise"""
    exploration_noise: float = 0
    """the scale of exploration noise"""
    learning_starts: int = 0
    """timestep to start learning"""
    policy_frequency: int = 2
    """the frequency of training policy (delayed)"""
    noise_clip: float = 0.5
    """noise clip parameter of the Target Policy Smoothing Regularization"""


def make_env(env_id, seed, idx, capture_video, run_name, initial_position=None):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = GoalTask(initial_position = initial_position)
        env.action_space.seed(seed)
        return env

    return thunk


# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod() + np.prod(env.action_space.shape), 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, x, a):
        x = torch.cat([x, a], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class Actor(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.fc1 = nn.Linear(np.array(env.observation_space.shape).prod(), 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc_mu = nn.Linear(32, np.prod(env.action_space.shape))
        # action rescaling
        self.register_buffer(
            "action_scale", torch.tensor((env.action_space.high - env.action_space.low) / 2.0, dtype=torch.float32)
        )
        self.register_buffer(
            "action_bias", torch.tensor((env.action_space.high + env.action_space.low) / 2.0, dtype=torch.float32)
        )

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.tanh(self.fc_mu(x))
        return x * self.action_scale + self.action_bias


class ESNLayer(nn.Module):
    def __init__(self, env, reservoir_size, spectral_radius=0.95, g=2.2, sparsity=0.1, device='cuda'):
        super(ESNLayer, self).__init__()
        
        self.device = device
        self.input_size = np.array(env.observation_space.shape).prod()
        self.reservoir_size = reservoir_size
        self.spectral_radius = spectral_radius
        self.g = g
        
        # Input weights: weights are sampled from a uniform distribution over [-0.5,0.5]
        self.W_in = torch.rand(reservoir_size, self.input_size, device=self.device) - 0.5
        
        # Reservoir weights: sparse random matrix
        self.W = torch.randn(reservoir_size, reservoir_size, device=self.device)
        self.W[torch.rand(reservoir_size, reservoir_size) > sparsity] = 0.0  # Sparsify
        
        # Scale the reservoir weights to have the desired spectral radius
        _, eigenvalues = torch.linalg.eig(self.W)
        max_eigenvalue = torch.max(torch.abs(eigenvalues))
        self.W *= self.spectral_radius / max_eigenvalue
        
        # The output weights, to be learned during training
        self.W_out = nn.Linear((reservoir_size+self.input_size), env.action_space.shape[0], device=self.device)
        
    
    def forward(self, u, hidden_state):
        # Compute the new reservoir state with leaky integration
        with torch.no_grad():
            next_hidden_state = torch.matmul(self.W_in, u.T) + self.g * torch.matmul(self.W, hidden_state.T)
            next_hidden_state = torch.tanh(next_hidden_state)
        self.next_hidden_state = next_hidden_state
        self.hidden_state = hidden_state
        # Append output prediction (linear transformation of the reservoir state)
        output = torch.tanh(self.W_out(torch.concat([next_hidden_state.T, u],dim=-1)))

        # Stack outputs over time and return
        return output
    
    def get_hiddenstate(self):
        return self.hidden_state, self.next_hidden_state
    
    def reset_state(self):
        """Reset the hidden state of the ESN."""
        self.hiddenstate = torch.zeros(self.reservoir_size)
    


def inference(actor, hidden_state, args, global_step):
    trajectory = []
    for initial_postion in args.initial_positions:
        inference_env = make_env(args.env_id, args.seed, 0, args.capture_video, run_name, initial_position=initial_postion)()
        # Implement goal change by input different goal area
        if global_step < args.total_timesteps/2:
            inference_env.change_goal((15,10))
        elif global_step >= args.total_timesteps/2:
            inference_env.change_goal((5,10))
        obs, _ = inference_env.reset() 
        hidden_state = hidden_state
        inference_actor = actor
        while True:
            with torch.no_grad():
                action = inference_actor(torch.Tensor(obs).to(device), torch.Tensor(hidden_state).to(device))
                action = action.cpu().numpy()
                next_obs, reward, termination, truncated, info = inference_env.step(action)
                _, next_hidden_state = inference_actor.get_hiddenstate()
                if termination:
                    break
                obs = next_obs
                hidden_state = next_hidden_state
        trajectory.append(inference_env.get_trajectory())
        inference_env.close()
    return trajectory

# %% [markdown]
# ### INITIALIZATION

# %%
import stable_baselines3 as sb3

if sb3.__version__ < "2.0":
    raise ValueError(
            """Ongoing migration: run the following command to install the new dependencies:
poetry run pip install "stable_baselines3==2.0.0a1"
"""
        )

args = Args()
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

# %%
# env setup
torch.manual_seed(args.seed)
envs = make_env(args.env_id, args.seed, 0, args.capture_video, run_name)()
envs.change_goal((15,10))
reservoir_size = 256
input_space = spaces.Box(low=-1, high=1, shape=(envs.observation_space.shape[0]+reservoir_size,), dtype=np.float32)

actor =  ESNLayer(envs, 256).to(device)
qf1 = QNetwork(envs).to(device)
qf2 = QNetwork(envs).to(device)
qf1_target = QNetwork(envs).to(device)
qf2_target = QNetwork(envs).to(device)
target_actor = ESNLayer(envs, 256).to(device)
target_actor.load_state_dict(actor.state_dict())
qf1_target.load_state_dict(qf1.state_dict())
qf2_target.load_state_dict(qf2.state_dict())
q_optimizer = optim.Adam(list(qf1.parameters()) + list(qf2.parameters()), lr=args.learning_rate)
actor_optimizer = optim.Adam(list(actor.parameters()), lr=args.learning_rate)

envs.observation_space.dtype = np.float32



rb = ReplayBuffer(
    args.buffer_size,
    input_space,
    envs.action_space,
    device,
    handle_timeout_termination=False,
)
start_time = time.time()

# %% [markdown]
# ### TEST RUN

# %%
obs, _ = envs.reset(seed=args.seed)
hidden_state = np.zeros((reservoir_size,))
input = np.concat((obs,hidden_state))
for i in range(400):
    obs = input[:envs.observation_space.shape[0]]
    hidden_state = input[envs.observation_space.shape[0]:]
    with torch.no_grad():
        actions = actor(torch.Tensor(obs).to(device), torch.Tensor(hidden_state).to(device))
        actions = actions.cpu().numpy()
    hidden_state, next_hidden_state = actor.get_hiddenstate()
    hidden_state, next_hidden_state = hidden_state.cpu(), next_hidden_state.cpu()
    next_obs, rewards, terminations, truncations, infos = envs.step(actions)
    input = input = np.concat((obs,hidden_state))
    next_input = np.concat((next_obs, next_hidden_state))
    rb.add(input, next_input, actions, rewards, terminations, infos)
    
    break

# %% [markdown]
# ### TRAIN

# %%
# TRY NOT TO MODIFY: start the game
obs, _ = envs.reset(seed=args.seed)
hidden_state = np.zeros((reservoir_size,))
input = np.concat((obs,hidden_state))
all_trajectory = {}
for global_step in range(args.total_timesteps):
    # CHANGE GOAL
    if global_step >= args.total_timesteps/2:
        envs.change_goal((5,10))

    # SAVE MODEL: save model per 2000 global steps
    model_dir = f"runs/{run_name}/models"
    os.makedirs(model_dir, exist_ok=True)
    if global_step % 2000 == 0 or global_step == args.total_timesteps:
        model_path = f"runs/{run_name}/models/{global_step}steps.cleanrl_model"
        torch.save(actor.state_dict(), model_path)


    obs = input[:envs.observation_space.shape[0]]
    hidden_state = input[envs.observation_space.shape[0]:]

    # INFERENCE:
    if global_step % 8000 == 0 or global_step == args.total_timesteps-1:
        args.initial_positions = [(2,2), (2,10), (2,18), (10,2), (10,18), (18,2), (18,10), (18,18)]
        trajectory = inference(actor, hidden_state, args, global_step)
        all_trajectory[f'{global_step}'] = trajectory


    # ALGO LOGIC: put action logic here
    if global_step < args.learning_starts:
        actions = envs.action_space.sample()
    else:
        with torch.no_grad():
            actions = actor(torch.Tensor(obs).to(device), torch.Tensor(hidden_state).to(device))
            actions = actions.cpu().numpy().clip(envs.action_space.low, envs.action_space.high)
            hidden_state, next_hidden_state = actor.get_hiddenstate()
            hidden_state, next_hidden_state = hidden_state.cpu(), next_hidden_state.cpu()

    # TRY NOT TO MODIFY: execute the game and log data.
    next_obs, rewards, terminations, truncations, infos = envs.step(actions)
    input = input = np.concat((obs,hidden_state))
    next_input = np.concat((next_obs, next_hidden_state))
    # TRY NOT TO MODIFY: record rewards for plotting purposes
    if "final_info" in infos or terminations:
        print(f"global_step={global_step}, episodic_return={infos['episode']['r']}")
        writer.add_scalar("charts/episodic_return", infos["episode"]["r"], global_step)
        writer.add_scalar("charts/episodic_length", infos["episode"]["l"], global_step)     

    # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
    next_obs = next_obs.copy()
    if truncations:
        real_next_obs = infos["final_observation"]
    rb.add(input, next_input, actions, rewards, terminations, infos)

    # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
    input = next_input

    # ALGO LOGIC: training.
    if global_step > args.learning_starts:
        data = rb.sample(args.batch_size)
        with torch.no_grad():
            next_observations = data.next_observations[:,:envs.observation_space.shape[0]]
            next_hidden_states = data.next_observations[:,envs.observation_space.shape[0]:]
            observations = data.observations[:,:envs.observation_space.shape[0]]
            hidden_states = data.observations[:,envs.observation_space.shape[0]:]
            next_state_actions = target_actor(next_observations, next_hidden_states).clamp(
                envs.action_space.low[0], envs.action_space.high[0]
            )
            qf1_next_target = qf1_target(next_observations, next_state_actions)
            qf2_next_target = qf2_target(next_observations, next_state_actions)
            min_qf_next_target = torch.min(qf1_next_target, qf2_next_target)
            next_q_value = data.rewards.flatten() + (1 - data.dones.flatten()) * args.gamma * (min_qf_next_target).view(-1)

        qf1_a_values = qf1(observations, data.actions).view(-1)
        qf2_a_values = qf2(observations, data.actions).view(-1)
        qf1_loss = F.mse_loss(qf1_a_values, next_q_value)
        qf2_loss = F.mse_loss(qf2_a_values, next_q_value)
        qf_loss = qf1_loss + qf2_loss

        # optimize the model
        q_optimizer.zero_grad()
        qf_loss.backward()
        q_optimizer.step()

        if global_step % args.policy_frequency == 0:
            actor_loss = -qf1(observations, actor(observations, hidden_states)).mean()
            actor_optimizer.zero_grad()
            actor_loss.backward()
            actor_optimizer.step()

            # update the target network
            for param, target_param in zip(actor.parameters(), target_actor.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
            for param, target_param in zip(qf1.parameters(), qf1_target.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
            for param, target_param in zip(qf2.parameters(), qf2_target.parameters()):
                target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)

        if global_step % 100 == 0:
            writer.add_scalar("losses/qf1_values", qf1_a_values.mean().item(), global_step)
            writer.add_scalar("losses/qf2_values", qf2_a_values.mean().item(), global_step)
            writer.add_scalar("losses/qf1_loss", qf1_loss.item(), global_step)
            writer.add_scalar("losses/qf2_loss", qf2_loss.item(), global_step)
            writer.add_scalar("losses/qf_loss", qf_loss.item() / 2.0, global_step)
            writer.add_scalar("losses/actor_loss", actor_loss.item(), global_step)
envs.close()
writer.close()

with open(f"runs/{run_name}/all_trajectory.pkl", "wb") as file:
    pickle.dump(all_trajectory, file)

# %% [markdown]
# ### PLOT

# %%
import matplotlib.pyplot as plt
fig_dir = f'runs/{run_name}/figures'
os.makedirs(fig_dir, exist_ok=True)
for trajectories in all_trajectory:
    step = int(trajectories)
    trajectories = all_trajectory[f'{trajectories}']
    fig, ax = plt.subplots(figsize=(10, 10))
    colors = plt.cm.tab10(np.linspace(0, 1, len(trajectories)))
    for i, (trajectory, color) in enumerate(zip(trajectories, colors)):
        ax.plot(trajectory[:, 0], trajectory[:, 1], color=color)
        ax.scatter(trajectory[:, 0], trajectory[:, 1], color=color, s=10)
    if step < args.total_timesteps/2:
        circle = plt.Circle((15, 10), radius=2, color='black', fill=False, linestyle='-', linewidth=2)
    elif step >= args.total_timesteps/2:
        circle = plt.Circle((5, 10), radius=2, color='black', fill=False, linestyle='-', linewidth=2)
    ax.add_patch(circle)
    plt.xlim(0, 20)
    plt.ylim(0, 20)
    plt.xlabel('X Position')
    plt.ylabel('Y Position')
    plt.title('Agent Trajectory in 2D Environment')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{fig_dir}/{step}.png')

# %% [markdown]
# ### RANDOM SEEDS

# %%
import stable_baselines3 as sb3

for i in range(10):
    if sb3.__version__ < "2.0":
        raise ValueError(
                """Ongoing migration: run the following command to install the new dependencies:
    poetry run pip install "stable_baselines3==2.0.0a1"
    """
            )

    args = Args()
    args.seed = random.randint(0, 2**32 - 1)
    run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
    if args.track:
        import wandb

        wandb.init(
            project=args.wandb_project_name,
            entity=args.wandb_entity,
            sync_tensorboard=True,
            config=vars(args),
            name=run_name,
            monitor_gym=True,
            save_code=True,
        )
    writer = SummaryWriter(f"runs/{run_name}")
    writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
    )

    # TRY NOT TO MODIFY: seeding
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = args.torch_deterministic

    device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

    # env setup
    torch.manual_seed(args.seed)
    envs = make_env(args.env_id, args.seed, 0, args.capture_video, run_name)()
    envs.change_goal((15,10))
    reservoir_size = 256
    input_space = spaces.Box(low=-1, high=1, shape=(envs.observation_space.shape[0]+reservoir_size,), dtype=np.float32)

    actor =  ESNLayer(envs, 256).to(device)
    qf1 = QNetwork(envs).to(device)
    qf2 = QNetwork(envs).to(device)
    qf1_target = QNetwork(envs).to(device)
    qf2_target = QNetwork(envs).to(device)
    target_actor = ESNLayer(envs, 256).to(device)
    target_actor.load_state_dict(actor.state_dict())
    qf1_target.load_state_dict(qf1.state_dict())
    qf2_target.load_state_dict(qf2.state_dict())
    q_optimizer = optim.Adam(list(qf1.parameters()) + list(qf2.parameters()), lr=args.learning_rate)
    actor_optimizer = optim.Adam(list(actor.parameters()), lr=args.learning_rate)

    envs.observation_space.dtype = np.float32



    rb = ReplayBuffer(
        args.buffer_size,
        input_space,
        envs.action_space,
        device,
        handle_timeout_termination=False,
    )
    start_time = time.time()

    # TRY NOT TO MODIFY: start the game
    obs, _ = envs.reset(seed=args.seed)
    hidden_state = np.zeros((reservoir_size,))
    input = np.concat((obs,hidden_state))
    all_trajectory = {}
    for global_step in range(args.total_timesteps):
        # CHANGE GOAL
        if global_step >= args.total_timesteps/2:
            envs.change_goal((5,10))

        # SAVE MODEL: save model per 2000 global steps
        model_dir = f"runs/{run_name}/models"
        os.makedirs(model_dir, exist_ok=True)
        if global_step % 2000 == 0 or global_step == args.total_timesteps:
            model_path = f"runs/{run_name}/models/{global_step}steps.cleanrl_model"
            torch.save(actor.state_dict(), model_path)


        obs = input[:envs.observation_space.shape[0]]
        hidden_state = input[envs.observation_space.shape[0]:]

        # INFERENCE:
        if global_step % 8000 == 0 or global_step == args.total_timesteps-1:
            args.initial_positions = [(2,2), (2,10), (2,18), (10,2), (10,18), (18,2), (18,10), (18,18)]
            trajectory = inference(actor, hidden_state, args, global_step)
            all_trajectory[f'{global_step}'] = trajectory


        # ALGO LOGIC: put action logic here
        if global_step < args.learning_starts:
            actions = envs.action_space.sample()
        else:
            with torch.no_grad():
                actions = actor(torch.Tensor(obs).to(device), torch.Tensor(hidden_state).to(device))
                actions = actions.cpu().numpy().clip(envs.action_space.low, envs.action_space.high)
                hidden_state, next_hidden_state = actor.get_hiddenstate()
                hidden_state, next_hidden_state = hidden_state.cpu(), next_hidden_state.cpu()

        # TRY NOT TO MODIFY: execute the game and log data.
        next_obs, rewards, terminations, truncations, infos = envs.step(actions)
        input = input = np.concat((obs,hidden_state))
        next_input = np.concat((next_obs, next_hidden_state))
        # TRY NOT TO MODIFY: record rewards for plotting purposes
        if "final_info" in infos or terminations:
            print(f"global_step={global_step}, episodic_return={infos['episode']['r']}")
            writer.add_scalar("charts/episodic_return", infos["episode"]["r"], global_step)
            writer.add_scalar("charts/episodic_length", infos["episode"]["l"], global_step)     

        # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
        next_obs = next_obs.copy()
        if truncations:
            real_next_obs = infos["final_observation"]
        rb.add(input, next_input, actions, rewards, terminations, infos)

        # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
        input = next_input

        # ALGO LOGIC: training.
        if global_step > args.learning_starts:
            data = rb.sample(args.batch_size)
            with torch.no_grad():
                next_observations = data.next_observations[:,:envs.observation_space.shape[0]]
                next_hidden_states = data.next_observations[:,envs.observation_space.shape[0]:]
                observations = data.observations[:,:envs.observation_space.shape[0]]
                hidden_states = data.observations[:,envs.observation_space.shape[0]:]
                next_state_actions = target_actor(next_observations, next_hidden_states).clamp(
                    envs.action_space.low[0], envs.action_space.high[0]
                )
                qf1_next_target = qf1_target(next_observations, next_state_actions)
                qf2_next_target = qf2_target(next_observations, next_state_actions)
                min_qf_next_target = torch.min(qf1_next_target, qf2_next_target)
                next_q_value = data.rewards.flatten() + (1 - data.dones.flatten()) * args.gamma * (min_qf_next_target).view(-1)

            qf1_a_values = qf1(observations, data.actions).view(-1)
            qf2_a_values = qf2(observations, data.actions).view(-1)
            qf1_loss = F.mse_loss(qf1_a_values, next_q_value)
            qf2_loss = F.mse_loss(qf2_a_values, next_q_value)
            qf_loss = qf1_loss + qf2_loss

            # optimize the model
            q_optimizer.zero_grad()
            qf_loss.backward()
            q_optimizer.step()

            if global_step % args.policy_frequency == 0:
                actor_loss = -qf1(observations, actor(observations, hidden_states)).mean()
                actor_optimizer.zero_grad()
                actor_loss.backward()
                actor_optimizer.step()

                # update the target network
                for param, target_param in zip(actor.parameters(), target_actor.parameters()):
                    target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
                for param, target_param in zip(qf1.parameters(), qf1_target.parameters()):
                    target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)
                for param, target_param in zip(qf2.parameters(), qf2_target.parameters()):
                    target_param.data.copy_(args.tau * param.data + (1 - args.tau) * target_param.data)

            if global_step % 100 == 0:
                writer.add_scalar("losses/qf1_values", qf1_a_values.mean().item(), global_step)
                writer.add_scalar("losses/qf2_values", qf2_a_values.mean().item(), global_step)
                writer.add_scalar("losses/qf1_loss", qf1_loss.item(), global_step)
                writer.add_scalar("losses/qf2_loss", qf2_loss.item(), global_step)
                writer.add_scalar("losses/qf_loss", qf_loss.item() / 2.0, global_step)
                writer.add_scalar("losses/actor_loss", actor_loss.item(), global_step)
    envs.close()
    writer.close()

    with open(f"runs/{run_name}/all_trajectory.pkl", "wb") as file:
        pickle.dump(all_trajectory, file)
# Out:
# C:\Users\24401\AppData\Local\Temp\ipykernel_25652\3498564268.py:157: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3687.)
#   next_hidden_state = torch.matmul(self.W_in, u.T) + self.g * torch.matmul(self.W, hidden_state.T)
# global_step=199, episodic_return=-0.04
# global_step=399, episodic_return=-0.11999999999999998
# global_step=599, episodic_return=-0.25000000000000006
# global_step=799, episodic_return=-0.34000000000000014
# global_step=999, episodic_return=-0.07
# global_step=1199, episodic_return=-0.13999999999999999
# global_step=1399, episodic_return=-0.16
# global_step=1599, episodic_return=-0.17
# global_step=1799, episodic_return=-0.11999999999999998
# global_step=1999, episodic_return=-0.04
# global_step=2199, episodic_return=-0.03
# global_step=2399, episodic_return=-0.09999999999999999
# global_step=2599, episodic_return=-0.15
# global_step=2799, episodic_return=-0.02
# global_step=2911, episodic_return=0.9
# global_step=3111, episodic_return=-0.34000000000000014
# global_step=3185, episodic_return=0.98
# global_step=3385, episodic_return=-0.6200000000000003
# global_step=3585, episodic_return=0
# global_step=3785, episodic_return=-0.05
# global_step=3937, episodic_return=0.97
# global_step=4078, episodic_return=0.99
# global_step=4162, episodic_return=1
# global_step=4362, episodic_return=-0.6700000000000004
# global_step=4462, episodic_return=0.88
# global_step=4568, episodic_return=0.5499999999999998
# global_step=4768, episodic_return=-0.37000000000000016
# global_step=4968, episodic_return=-0.4000000000000002
# global_step=5032, episodic_return=1
# global_step=5093, episodic_return=0.87
# global_step=5163, episodic_return=1
# global_step=5241, episodic_return=0.95
# global_step=5291, episodic_return=0.95
# global_step=5491, episodic_return=-0.4300000000000002
# global_step=5673, episodic_return=0.8099999999999999
# global_step=5827, episodic_return=0.97
# global_step=6027, episodic_return=-0.04
# global_step=6172, episodic_return=0.92
# global_step=6265, episodic_return=0.98
# global_step=6465, episodic_return=-0.25000000000000006
# global_step=6523, episodic_return=0.96
# global_step=6723, episodic_return=-0.060000000000000005
# global_step=6886, episodic_return=1
# global_step=6909, episodic_return=1
# global_step=7099, episodic_return=0.48999999999999977
# global_step=7163, episodic_return=0.82
# global_step=7251, episodic_return=0.95
# global_step=7451, episodic_return=-0.3100000000000001
# global_step=7519, episodic_return=1
# global_step=7614, episodic_return=0.86
# global_step=7778, episodic_return=0.82
# global_step=7806, episodic_return=0.98
# global_step=7853, episodic_return=0.96
# global_step=7880, episodic_return=1
# global_step=8080, episodic_return=-0.12999999999999998
# global_step=8136, episodic_return=1
# global_step=8169, episodic_return=1
# global_step=8199, episodic_return=0.99
# global_step=8297, episodic_return=1
# global_step=8322, episodic_return=0.99
# global_step=8429, episodic_return=0.99
# global_step=8581, episodic_return=0.96
# global_step=8750, episodic_return=0.97
# global_step=8813, episodic_return=0.95
# global_step=8927, episodic_return=0.97
# global_step=9042, episodic_return=1
# global_step=9059, episodic_return=1
# global_step=9169, episodic_return=0.87
# global_step=9239, episodic_return=0.86
# global_step=9349, episodic_return=1
# global_step=9375, episodic_return=0.99
# global_step=9423, episodic_return=0.9299999999999999
# global_step=9458, episodic_return=0.97
# global_step=9606, episodic_return=0.99
# global_step=9656, episodic_return=0.96
# global_step=9762, episodic_return=1
# global_step=9849, episodic_return=0.94
# global_step=9888, episodic_return=0.97
# global_step=9964, episodic_return=0.96
# global_step=10055, episodic_return=1
# global_step=10066, episodic_return=1
# global_step=10096, episodic_return=1
# global_step=10185, episodic_return=0.97
# global_step=10323, episodic_return=0.98
# global_step=10340, episodic_return=1
# global_step=10378, episodic_return=0.99
# global_step=10578, episodic_return=-0.5400000000000003
# global_step=10645, episodic_return=1
# global_step=10729, episodic_return=1
# global_step=10855, episodic_return=0.92
# global_step=10890, episodic_return=0.98
# global_step=10956, episodic_return=1
# global_step=11025, episodic_return=0.7899999999999999
# global_step=11036, episodic_return=1
# global_step=11057, episodic_return=1
# global_step=11114, episodic_return=0.96
# global_step=11140, episodic_return=0.97
# global_step=11308, episodic_return=0.82
# global_step=11359, episodic_return=1
# global_step=11488, episodic_return=1
# global_step=11558, episodic_return=1
# global_step=11652, episodic_return=0.98
# global_step=11689, episodic_return=0.97
# global_step=11735, episodic_return=1
# global_step=11770, episodic_return=1
# global_step=11831, episodic_return=0.97
# global_step=11868, episodic_return=1
# global_step=11908, episodic_return=0.94
# global_step=11948, episodic_return=0.88
# global_step=11993, episodic_return=0.97
# global_step=12048, episodic_return=1
# global_step=12061, episodic_return=1
# global_step=12135, episodic_return=1
# global_step=12198, episodic_return=1
# global_step=12371, episodic_return=0.7
# global_step=12474, episodic_return=0.82
# global_step=12507, episodic_return=1
# global_step=12547, episodic_return=0.99
# global_step=12587, episodic_return=0.9299999999999999
# global_step=12659, episodic_return=1
# global_step=12695, episodic_return=0.96
# global_step=12762, episodic_return=0.88
# global_step=12859, episodic_return=1
# global_step=12886, episodic_return=1
# global_step=13004, episodic_return=0.95
# global_step=13047, episodic_return=0.99
# global_step=13093, episodic_return=0.96
# global_step=13143, episodic_return=0.84
# global_step=13165, episodic_return=1
# global_step=13258, episodic_return=0.7899999999999999
# global_step=13331, episodic_return=0.94
# global_step=13367, episodic_return=1
# global_step=13412, episodic_return=0.92
# global_step=13446, episodic_return=1
# global_step=13474, episodic_return=0.98
# global_step=13513, episodic_return=0.99
# global_step=13587, episodic_return=0.94
# global_step=13613, episodic_return=1
# global_step=13638, episodic_return=1
# global_step=13656, episodic_return=1
# global_step=13758, episodic_return=1
# global_step=13778, episodic_return=0.98
# global_step=13946, episodic_return=1
# global_step=14018, episodic_return=0.98
# global_step=14077, episodic_return=0.95
# global_step=14156, episodic_return=1
# global_step=14265, episodic_return=0.99
# global_step=14319, episodic_return=0.98
# global_step=14347, episodic_return=0.95
# global_step=14390, episodic_return=1
# global_step=14426, episodic_return=0.96
# global_step=14436, episodic_return=1
# global_step=14461, episodic_return=0.98
# global_step=14489, episodic_return=1
# global_step=14609, episodic_return=0.97
# global_step=14727, episodic_return=0.83
# global_step=14775, episodic_return=1
# global_step=14904, episodic_return=0.98
# global_step=14973, episodic_return=0.94
# global_step=15096, episodic_return=1
# global_step=15143, episodic_return=1
# global_step=15187, episodic_return=0.9299999999999999
# global_step=15247, episodic_return=1
# global_step=15319, episodic_return=0.98
# global_step=15374, episodic_return=0.98
# global_step=15413, episodic_return=0.95
# global_step=15446, episodic_return=1
# global_step=15485, episodic_return=1
# global_step=15526, episodic_return=0.99
# global_step=15540, episodic_return=1
# global_step=15622, episodic_return=1
# global_step=15713, episodic_return=0.94
# global_step=15844, episodic_return=0.83
# global_step=15859, episodic_return=1
# global_step=15901, episodic_return=1
# global_step=15945, episodic_return=1
# global_step=16024, episodic_return=0.99
# global_step=16066, episodic_return=1
# global_step=16096, episodic_return=1
# global_step=16115, episodic_return=1
# global_step=16137, episodic_return=0.96
# global_step=16176, episodic_return=0.9
# global_step=16231, episodic_return=1
# global_step=16268, episodic_return=1
# global_step=16274, episodic_return=1
# global_step=16399, episodic_return=0.86
# global_step=16436, episodic_return=1
# global_step=16487, episodic_return=1
# global_step=16547, episodic_return=0.92
# global_step=16612, episodic_return=0.94
# global_step=16691, episodic_return=1
# global_step=16742, episodic_return=1
# global_step=16763, episodic_return=0.94
# global_step=16878, episodic_return=1
# global_step=16912, episodic_return=0.98
# global_step=16958, episodic_return=1
# global_step=16966, episodic_return=1
# global_step=17012, episodic_return=1
# global_step=17019, episodic_return=1
# global_step=17062, episodic_return=0.98
# global_step=17071, episodic_return=1
# global_step=17134, episodic_return=1
# global_step=17194, episodic_return=0.98
# global_step=17220, episodic_return=0.99
# global_step=17307, episodic_return=1
# global_step=17343, episodic_return=1
# global_step=17362, episodic_return=1
# global_step=17412, episodic_return=0.99
# global_step=17442, episodic_return=1
# global_step=17483, episodic_return=0.99
# global_step=17510, episodic_return=1
# global_step=17533, episodic_return=0.96
# global_step=17540, episodic_return=1
# global_step=17636, episodic_return=0.98
# global_step=17707, episodic_return=1
# global_step=17723, episodic_return=1
# global_step=17819, episodic_return=1
# global_step=17865, episodic_return=1
# global_step=17903, episodic_return=0.99
# global_step=18008, episodic_return=0.95
# global_step=18091, episodic_return=0.99
# global_step=18121, episodic_return=0.98
# global_step=18163, episodic_return=0.92
# global_step=18221, episodic_return=0.87
# global_step=18256, episodic_return=1
# global_step=18287, episodic_return=1
# global_step=18341, episodic_return=0.99
# global_step=18359, episodic_return=1
# global_step=18371, episodic_return=1
# global_step=18433, episodic_return=0.99
# global_step=18454, episodic_return=1
# global_step=18490, episodic_return=0.98
# global_step=18563, episodic_return=0.98
# global_step=18624, episodic_return=1
# global_step=18637, episodic_return=1
# global_step=18718, episodic_return=0.98
# global_step=18762, episodic_return=0.91
# global_step=18777, episodic_return=1
# global_step=18802, episodic_return=1
# global_step=18846, episodic_return=1
# global_step=18878, episodic_return=1
# global_step=18938, episodic_return=1
# global_step=19029, episodic_return=1
# global_step=19073, episodic_return=1
# global_step=19114, episodic_return=1
# global_step=19193, episodic_return=1
# global_step=19218, episodic_return=0.98
# global_step=19266, episodic_return=0.92
# global_step=19300, episodic_return=1
# global_step=19329, episodic_return=1
# global_step=19368, episodic_return=0.99
# global_step=19440, episodic_return=0.92
# global_step=19461, episodic_return=1
# global_step=19507, episodic_return=1
# global_step=19537, episodic_return=1
# global_step=19571, episodic_return=1
# global_step=19601, episodic_return=0.94
# global_step=19623, episodic_return=1
# global_step=19665, episodic_return=0.99
# global_step=19681, episodic_return=1
# global_step=19802, episodic_return=0.99
# global_step=19826, episodic_return=0.99
# global_step=19862, episodic_return=1
# global_step=19906, episodic_return=0.95
# global_step=19919, episodic_return=1
# global_step=19970, episodic_return=1
# global_step=19996, episodic_return=1
# global_step=20166, episodic_return=0.75
# global_step=20197, episodic_return=1
# global_step=20231, episodic_return=1
# global_step=20270, episodic_return=1
# global_step=20288, episodic_return=1
# global_step=20324, episodic_return=0.94
# global_step=20393, episodic_return=1
# global_step=20434, episodic_return=0.99
# global_step=20511, episodic_return=0.99
# global_step=20530, episodic_return=1
# global_step=20570, episodic_return=0.96
# global_step=20611, episodic_return=1
# global_step=20649, episodic_return=1
# global_step=20696, episodic_return=1
# global_step=20741, episodic_return=1
# global_step=20775, episodic_return=0.99
# global_step=20794, episodic_return=0.99
# global_step=20812, episodic_return=1
# global_step=20854, episodic_return=0.97
# global_step=20927, episodic_return=1
# global_step=20964, episodic_return=1
# global_step=20995, episodic_return=1
# global_step=21009, episodic_return=1
# global_step=21025, episodic_return=1
# global_step=21051, episodic_return=1
# global_step=21089, episodic_return=1
# global_step=21118, episodic_return=0.99
# global_step=21137, episodic_return=1
# global_step=21149, episodic_return=1
# global_step=21179, episodic_return=1
# global_step=21201, episodic_return=1
# global_step=21238, episodic_return=1
# global_step=21269, episodic_return=1
# global_step=21289, episodic_return=1
# global_step=21334, episodic_return=1
# global_step=21390, episodic_return=1
# global_step=21412, episodic_return=1
# global_step=21462, episodic_return=1
# global_step=21504, episodic_return=0.95
# global_step=21524, episodic_return=1
# global_step=21559, episodic_return=1
# global_step=21605, episodic_return=0.87
# global_step=21627, episodic_return=1
# global_step=21677, episodic_return=0.89
# global_step=21711, episodic_return=0.92
# global_step=21761, episodic_return=0.94
# global_step=21798, episodic_return=1
# global_step=21831, episodic_return=1
# global_step=21855, episodic_return=0.97
# global_step=21888, episodic_return=0.99
# global_step=21929, episodic_return=0.98
# global_step=21957, episodic_return=1
# global_step=22011, episodic_return=0.9
# global_step=22035, episodic_return=0.96
# global_step=22129, episodic_return=0.95
# global_step=22170, episodic_return=1
# global_step=22220, episodic_return=0.94
# global_step=22239, episodic_return=1
# global_step=22255, episodic_return=1
# global_step=22292, episodic_return=1
# global_step=22331, episodic_return=1
# global_step=22356, episodic_return=1
# global_step=22369, episodic_return=1
# global_step=22391, episodic_return=1
# global_step=22411, episodic_return=1
# global_step=22439, episodic_return=1
# global_step=22453, episodic_return=1
# global_step=22475, episodic_return=0.99
# global_step=22494, episodic_return=1
# global_step=22539, episodic_return=1
# global_step=22561, episodic_return=0.96
# global_step=22609, episodic_return=0.94
# global_step=22624, episodic_return=0.98
# global_step=22661, episodic_return=1
# global_step=22676, episodic_return=1
# global_step=22701, episodic_return=0.96
# global_step=22711, episodic_return=1
# global_step=22748, episodic_return=1
# global_step=22767, episodic_return=0.98
# global_step=22786, episodic_return=1
# global_step=22816, episodic_return=1
# global_step=22865, episodic_return=1
# global_step=22911, episodic_return=1
# global_step=22927, episodic_return=0.99
# global_step=22954, episodic_return=1
# global_step=22984, episodic_return=0.98
# global_step=23040, episodic_return=0.98
# global_step=23064, episodic_return=1
# global_step=23108, episodic_return=0.96
# global_step=23175, episodic_return=0.91
# global_step=23202, episodic_return=1
# global_step=23236, episodic_return=1
# global_step=23253, episodic_return=1
# global_step=23295, episodic_return=1
# global_step=23319, episodic_return=1
# global_step=23352, episodic_return=0.99
# global_step=23375, episodic_return=0.94
# global_step=23390, episodic_return=1
# global_step=23407, episodic_return=1
# global_step=23471, episodic_return=1
# global_step=23482, episodic_return=1
# global_step=23529, episodic_return=1
# global_step=23546, episodic_return=0.98
# global_step=23573, episodic_return=0.99
# global_step=23621, episodic_return=1
# global_step=23642, episodic_return=1
# global_step=23680, episodic_return=1
# global_step=23695, episodic_return=1
# global_step=23715, episodic_return=0.98
# global_step=23736, episodic_return=0.98
# global_step=23764, episodic_return=1
# global_step=23783, episodic_return=1
# global_step=23807, episodic_return=0.99
# global_step=23847, episodic_return=1
# global_step=23873, episodic_return=1
# global_step=23896, episodic_return=1
# global_step=23928, episodic_return=0.98
# global_step=23997, episodic_return=1
# global_step=24019, episodic_return=1
# global_step=24044, episodic_return=1
# global_step=24111, episodic_return=0.92
# global_step=24121, episodic_return=1
# global_step=24145, episodic_return=0.99
# global_step=24210, episodic_return=1
# global_step=24248, episodic_return=1
# global_step=24279, episodic_return=0.99
# global_step=24297, episodic_return=1
# global_step=24350, episodic_return=1
# global_step=24415, episodic_return=1
# global_step=24440, episodic_return=1
# global_step=24472, episodic_return=1
# global_step=24500, episodic_return=1
# global_step=24532, episodic_return=0.99
# global_step=24581, episodic_return=1
# global_step=24606, episodic_return=0.94
# global_step=24618, episodic_return=1
# global_step=24642, episodic_return=1
# global_step=24691, episodic_return=0.98
# global_step=24730, episodic_return=1
# global_step=24754, episodic_return=0.98
# global_step=24772, episodic_return=0.99
# global_step=24809, episodic_return=0.94
# global_step=24838, episodic_return=1
# global_step=24866, episodic_return=1
# global_step=24887, episodic_return=1
# global_step=24935, episodic_return=1
# global_step=24994, episodic_return=0.95
# global_step=25013, episodic_return=1
# global_step=25024, episodic_return=1
# global_step=25062, episodic_return=1
# global_step=25091, episodic_return=0.99
# global_step=25160, episodic_return=1
# global_step=25178, episodic_return=0.99
# global_step=25213, episodic_return=1
# global_step=25250, episodic_return=1
# global_step=25271, episodic_return=1
# global_step=25296, episodic_return=1
# global_step=25321, episodic_return=0.99
# global_step=25349, episodic_return=1
# global_step=25378, episodic_return=1
# global_step=25393, episodic_return=0.98
# global_step=25425, episodic_return=1
# global_step=25443, episodic_return=1
# global_step=25457, episodic_return=1
# global_step=25485, episodic_return=0.9299999999999999
# global_step=25520, episodic_return=1
# global_step=25595, episodic_return=0.9299999999999999
# global_step=25620, episodic_return=1
# global_step=25640, episodic_return=1
# global_step=25680, episodic_return=1
# global_step=25689, episodic_return=1
# global_step=25718, episodic_return=0.98
# global_step=25747, episodic_return=0.96
# global_step=25771, episodic_return=0.99
# global_step=25791, episodic_return=1
# global_step=25813, episodic_return=1
# global_step=25830, episodic_return=1
# global_step=25847, episodic_return=1
# global_step=25881, episodic_return=1
# global_step=25934, episodic_return=0.99
# global_step=25956, episodic_return=1
# global_step=25996, episodic_return=0.99
# global_step=26012, episodic_return=1
# global_step=26032, episodic_return=1
# global_step=26079, episodic_return=1
# global_step=26114, episodic_return=1
# global_step=26135, episodic_return=0.99
# global_step=26150, episodic_return=1
# global_step=26183, episodic_return=0.99
# global_step=26198, episodic_return=1
# global_step=26233, episodic_return=1
# global_step=26259, episodic_return=1
# global_step=26281, episodic_return=1
# global_step=26318, episodic_return=0.96
# global_step=26355, episodic_return=0.94
# global_step=26400, episodic_return=0.99
# global_step=26418, episodic_return=1
# global_step=26463, episodic_return=1
# global_step=26498, episodic_return=0.9
# global_step=26527, episodic_return=0.99
# global_step=26564, episodic_return=0.96
# global_step=26598, episodic_return=0.99
# global_step=26645, episodic_return=1
# global_step=26694, episodic_return=1
# global_step=26737, episodic_return=0.98
# global_step=26771, episodic_return=1
# global_step=26789, episodic_return=1
# global_step=26815, episodic_return=1
# global_step=26857, episodic_return=1
# global_step=26871, episodic_return=1
# global_step=26909, episodic_return=0.96
# global_step=26943, episodic_return=1
# global_step=26961, episodic_return=0.98
# global_step=26989, episodic_return=0.98
# global_step=27031, episodic_return=1
# global_step=27072, episodic_return=1
# global_step=27103, episodic_return=1
# global_step=27117, episodic_return=1
# global_step=27133, episodic_return=1
# global_step=27148, episodic_return=1
# global_step=27167, episodic_return=1
# global_step=27184, episodic_return=1
# global_step=27203, episodic_return=1
# global_step=27217, episodic_return=1
# global_step=27250, episodic_return=1
# global_step=27308, episodic_return=0.98
# global_step=27334, episodic_return=1
# global_step=27352, episodic_return=0.99
# global_step=27368, episodic_return=1
# global_step=27395, episodic_return=1
# global_step=27427, episodic_return=1
# global_step=27437, episodic_return=1
# global_step=27474, episodic_return=0.99
# global_step=27509, episodic_return=1
# global_step=27531, episodic_return=1
# global_step=27562, episodic_return=0.99
# global_step=27594, episodic_return=1
# global_step=27621, episodic_return=1
# global_step=27649, episodic_return=1
# global_step=27665, episodic_return=1
# global_step=27754, episodic_return=0.86
# global_step=27765, episodic_return=1
# global_step=27785, episodic_return=1
# global_step=27803, episodic_return=1
# global_step=27818, episodic_return=1
# global_step=27835, episodic_return=1
# global_step=27844, episodic_return=1
# global_step=27887, episodic_return=1
# global_step=27905, episodic_return=1
# global_step=27936, episodic_return=1
# global_step=27968, episodic_return=0.99
# global_step=27999, episodic_return=0.98
# global_step=28016, episodic_return=1
# global_step=28033, episodic_return=1
# global_step=28069, episodic_return=1
# global_step=28088, episodic_return=1
# global_step=28122, episodic_return=1
# global_step=28171, episodic_return=1
# global_step=28226, episodic_return=1
# global_step=28283, episodic_return=1
# global_step=28292, episodic_return=1
# global_step=28315, episodic_return=1
# global_step=28366, episodic_return=1
# global_step=28402, episodic_return=1
# global_step=28456, episodic_return=1
# global_step=28476, episodic_return=0.99
# global_step=28501, episodic_return=1
# global_step=28553, episodic_return=0.97
# global_step=28572, episodic_return=1
# global_step=28623, episodic_return=0.92
# global_step=28638, episodic_return=1
# global_step=28657, episodic_return=0.97
# global_step=28706, episodic_return=1
# global_step=28719, episodic_return=0.97
# global_step=28738, episodic_return=1
# global_step=28769, episodic_return=1
# global_step=28792, episodic_return=1
# global_step=28811, episodic_return=0.98
# global_step=28829, episodic_return=1
# global_step=28843, episodic_return=1
# global_step=28880, episodic_return=1
# global_step=28902, episodic_return=1
# global_step=28922, episodic_return=1
# global_step=28939, episodic_return=1
# global_step=28975, episodic_return=0.91
# global_step=28999, episodic_return=0.99
# global_step=29030, episodic_return=0.97
# global_step=29048, episodic_return=0.99
# global_step=29058, episodic_return=0.98
# global_step=29081, episodic_return=1
# global_step=29094, episodic_return=1
# global_step=29113, episodic_return=1
# global_step=29145, episodic_return=1
# global_step=29180, episodic_return=0.98
# global_step=29204, episodic_return=1
# global_step=29226, episodic_return=1
# global_step=29247, episodic_return=1
# global_step=29264, episodic_return=1
# global_step=29292, episodic_return=0.98
# global_step=29340, episodic_return=1
# global_step=29379, episodic_return=1
# global_step=29406, episodic_return=1
# global_step=29426, episodic_return=0.97
# global_step=29444, episodic_return=1
# global_step=29457, episodic_return=1
# global_step=29482, episodic_return=1
# global_step=29525, episodic_return=1
# global_step=29576, episodic_return=1
# global_step=29591, episodic_return=1
# global_step=29612, episodic_return=0.99
# global_step=29645, episodic_return=1
# global_step=29672, episodic_return=0.98
# global_step=29684, episodic_return=1
# global_step=29700, episodic_return=0.99
# global_step=29719, episodic_return=0.99
# global_step=29752, episodic_return=0.99
# global_step=29775, episodic_return=0.89
# global_step=29821, episodic_return=1
# global_step=29842, episodic_return=1
# global_step=29858, episodic_return=1
# global_step=29865, episodic_return=1
# global_step=29903, episodic_return=1
# global_step=29936, episodic_return=1
# global_step=29966, episodic_return=0.99
# global_step=29992, episodic_return=1
# global_step=30019, episodic_return=1
# global_step=30033, episodic_return=1
# global_step=30056, episodic_return=1
# global_step=30073, episodic_return=1
# global_step=30096, episodic_return=1
# global_step=30115, episodic_return=0.98
# global_step=30139, episodic_return=1
# global_step=30174, episodic_return=1
# global_step=30194, episodic_return=1
# global_step=30229, episodic_return=0.99
# global_step=30254, episodic_return=1
# global_step=30266, episodic_return=1
# global_step=30282, episodic_return=1
# global_step=30295, episodic_return=1
# global_step=30331, episodic_return=0.98
# global_step=30350, episodic_return=1
# global_step=30357, episodic_return=1
# global_step=30374, episodic_return=0.98
# global_step=30392, episodic_return=1
# global_step=30410, episodic_return=1
# global_step=30440, episodic_return=0.97
# global_step=30471, episodic_return=1
# global_step=30500, episodic_return=1
# global_step=30533, episodic_return=1
# global_step=30549, episodic_return=1
# global_step=30569, episodic_return=1
# global_step=30596, episodic_return=1
# global_step=30617, episodic_return=1
# global_step=30662, episodic_return=0.97
# global_step=30681, episodic_return=1
# global_step=30713, episodic_return=0.99
# global_step=30759, episodic_return=1
# global_step=30791, episodic_return=1
# global_step=30831, episodic_return=0.98
# global_step=30854, episodic_return=1
# global_step=30880, episodic_return=1
# global_step=30902, episodic_return=0.99
# global_step=30952, episodic_return=1
# global_step=30977, episodic_return=1
# global_step=30993, episodic_return=1
# global_step=31011, episodic_return=1
# global_step=31040, episodic_return=1
# global_step=31069, episodic_return=1
# global_step=31083, episodic_return=1
# global_step=31112, episodic_return=0.98
# global_step=31143, episodic_return=1
# global_step=31165, episodic_return=1
# global_step=31179, episodic_return=1
# global_step=31212, episodic_return=0.95
# global_step=31230, episodic_return=1
# global_step=31245, episodic_return=1
# global_step=31268, episodic_return=1
# global_step=31301, episodic_return=1
# global_step=31324, episodic_return=1
# global_step=31344, episodic_return=0.99
# global_step=31373, episodic_return=1
# global_step=31392, episodic_return=1
# global_step=31433, episodic_return=1
# global_step=31457, episodic_return=1
# global_step=31483, episodic_return=0.95
# global_step=31519, episodic_return=0.99
# global_step=31543, episodic_return=0.97
# global_step=31580, episodic_return=0.99
# global_step=31602, episodic_return=1
# global_step=31628, episodic_return=1
# global_step=31650, episodic_return=1
# global_step=31682, episodic_return=1
# global_step=31700, episodic_return=1
# global_step=31725, episodic_return=1
# global_step=31755, episodic_return=1
# global_step=31770, episodic_return=0.98
# global_step=31786, episodic_return=1
# global_step=31807, episodic_return=0.99
# global_step=31825, episodic_return=1
# global_step=31849, episodic_return=1
# global_step=31879, episodic_return=0.99
# global_step=31908, episodic_return=0.99
# global_step=31942, episodic_return=1
# global_step=31972, episodic_return=1
# global_step=32000, episodic_return=1
# global_step=32036, episodic_return=1
# global_step=32050, episodic_return=1
# global_step=32070, episodic_return=1
# global_step=32103, episodic_return=1
# global_step=32125, episodic_return=1
# global_step=32172, episodic_return=1
# global_step=32204, episodic_return=1
# global_step=32224, episodic_return=1
# global_step=32241, episodic_return=1
# global_step=32253, episodic_return=1
# global_step=32274, episodic_return=1
# global_step=32294, episodic_return=1
# global_step=32308, episodic_return=0.99
# global_step=32345, episodic_return=1
# global_step=32382, episodic_return=1
# global_step=32396, episodic_return=1
# global_step=32422, episodic_return=1
# global_step=32448, episodic_return=0.99
# global_step=32472, episodic_return=1
# global_step=32500, episodic_return=1
# global_step=32523, episodic_return=0.98
# global_step=32556, episodic_return=0.99
# global_step=32565, episodic_return=1
# global_step=32585, episodic_return=1
# global_step=32617, episodic_return=1
# global_step=32631, episodic_return=0.98
# global_step=32650, episodic_return=1
# global_step=32675, episodic_return=1
# global_step=32700, episodic_return=1
# global_step=32719, episodic_return=1
# global_step=32734, episodic_return=0.99
# global_step=32759, episodic_return=1
# global_step=32780, episodic_return=1
# global_step=32793, episodic_return=0.98
# global_step=32815, episodic_return=1
# global_step=32839, episodic_return=1
# global_step=32859, episodic_return=1
# global_step=32877, episodic_return=1
# global_step=32898, episodic_return=1
# global_step=32914, episodic_return=1
# global_step=32933, episodic_return=0.99
# global_step=32950, episodic_return=0.97
# global_step=32973, episodic_return=1
# global_step=32986, episodic_return=1
# global_step=33001, episodic_return=1
# global_step=33019, episodic_return=1
# global_step=33031, episodic_return=1
# global_step=33068, episodic_return=1
# global_step=33100, episodic_return=1
# global_step=33135, episodic_return=1
# global_step=33173, episodic_return=1
# global_step=33201, episodic_return=1
# global_step=33220, episodic_return=0.99
# global_step=33245, episodic_return=1
# global_step=33266, episodic_return=1
# global_step=33276, episodic_return=1
# global_step=33288, episodic_return=1
# global_step=33326, episodic_return=0.98
# global_step=33351, episodic_return=1
# global_step=33369, episodic_return=1
# global_step=33403, episodic_return=1
# global_step=33432, episodic_return=0.98
# global_step=33460, episodic_return=1
# global_step=33493, episodic_return=1
# global_step=33502, episodic_return=1
# global_step=33515, episodic_return=1
# global_step=33540, episodic_return=1
# global_step=33561, episodic_return=0.99
# global_step=33626, episodic_return=1
# global_step=33657, episodic_return=1
# global_step=33679, episodic_return=0.99
# global_step=33709, episodic_return=0.99
# global_step=33743, episodic_return=1
# global_step=33761, episodic_return=1
# global_step=33793, episodic_return=0.99
# global_step=33815, episodic_return=1
# global_step=33832, episodic_return=1
# global_step=33854, episodic_return=1
# global_step=33876, episodic_return=1
# global_step=33896, episodic_return=1
# global_step=33922, episodic_return=0.96
# global_step=33957, episodic_return=0.99
# global_step=33980, episodic_return=1
# global_step=33996, episodic_return=0.99
# global_step=34020, episodic_return=1
# global_step=34046, episodic_return=1
# global_step=34065, episodic_return=1
# global_step=34086, episodic_return=1
# global_step=34106, episodic_return=0.99
# global_step=34147, episodic_return=0.96
# global_step=34172, episodic_return=0.96
# global_step=34181, episodic_return=1
# global_step=34200, episodic_return=1
# global_step=34216, episodic_return=1
# global_step=34240, episodic_return=1
# global_step=34258, episodic_return=1
# global_step=34271, episodic_return=1
# global_step=34294, episodic_return=1
# global_step=34326, episodic_return=1
# global_step=34338, episodic_return=0.97
# global_step=34359, episodic_return=1
# global_step=34380, episodic_return=0.99
# global_step=34397, episodic_return=1
# global_step=34409, episodic_return=0.99
# global_step=34431, episodic_return=0.99
# global_step=34453, episodic_return=1
# global_step=34479, episodic_return=0.97
# global_step=34492, episodic_return=1
# global_step=34525, episodic_return=1
# global_step=34545, episodic_return=1
# global_step=34563, episodic_return=1
# global_step=34572, episodic_return=1
# global_step=34589, episodic_return=1
# global_step=34611, episodic_return=0.98
# global_step=34628, episodic_return=1
# global_step=34640, episodic_return=1
# global_step=34658, episodic_return=1
# global_step=34685, episodic_return=0.99
# global_step=34700, episodic_return=1
# global_step=34722, episodic_return=1
# global_step=34735, episodic_return=1
# global_step=34744, episodic_return=1
# global_step=34760, episodic_return=1
# global_step=34779, episodic_return=1
# global_step=34797, episodic_return=1
# global_step=34813, episodic_return=1
# global_step=34834, episodic_return=1
# global_step=34852, episodic_return=1
# global_step=34867, episodic_return=1
# global_step=34885, episodic_return=0.99
# global_step=34916, episodic_return=0.99
# global_step=34937, episodic_return=0.99
# global_step=34952, episodic_return=1
# global_step=34963, episodic_return=1
# global_step=34988, episodic_return=1
# global_step=35020, episodic_return=1
# global_step=35040, episodic_return=1
# global_step=35065, episodic_return=1
# global_step=35079, episodic_return=1
# global_step=35089, episodic_return=1
# global_step=35117, episodic_return=0.99
# global_step=35141, episodic_return=0.98
# global_step=35169, episodic_return=1
# global_step=35193, episodic_return=1
# global_step=35228, episodic_return=1
# global_step=35251, episodic_return=1
# global_step=35271, episodic_return=0.99
# global_step=35294, episodic_return=1
# global_step=35316, episodic_return=0.98
# global_step=35364, episodic_return=1
# global_step=35384, episodic_return=1
# global_step=35438, episodic_return=1
# global_step=35472, episodic_return=1
# global_step=35492, episodic_return=1
# global_step=35510, episodic_return=1
# global_step=35518, episodic_return=1
# global_step=35531, episodic_return=1
# global_step=35568, episodic_return=1
# global_step=35586, episodic_return=1
# global_step=35603, episodic_return=1
# global_step=35634, episodic_return=1
# global_step=35655, episodic_return=1
# global_step=35700, episodic_return=1
# global_step=35723, episodic_return=1
# global_step=35750, episodic_return=1
# global_step=35768, episodic_return=1
# global_step=35782, episodic_return=1
# global_step=35796, episodic_return=1
# global_step=35822, episodic_return=1
# global_step=35844, episodic_return=1
# global_step=35856, episodic_return=1
# global_step=35876, episodic_return=1
# global_step=35901, episodic_return=1
# global_step=35930, episodic_return=1
# global_step=35952, episodic_return=1
# global_step=35979, episodic_return=1
# global_step=36002, episodic_return=1
# global_step=36034, episodic_return=1
# global_step=36057, episodic_return=0.99
# global_step=36068, episodic_return=1
# global_step=36123, episodic_return=0.98
# global_step=36148, episodic_return=1
# global_step=36165, episodic_return=1
# global_step=36182, episodic_return=0.99
# global_step=36211, episodic_return=0.99
# global_step=36227, episodic_return=1
# global_step=36238, episodic_return=1
# global_step=36256, episodic_return=1
# global_step=36283, episodic_return=1
# global_step=36296, episodic_return=1
# global_step=36321, episodic_return=1
# global_step=36333, episodic_return=1
# global_step=36355, episodic_return=1
# global_step=36364, episodic_return=1
# global_step=36380, episodic_return=1
# global_step=36390, episodic_return=1
# global_step=36437, episodic_return=1
# global_step=36458, episodic_return=1
# global_step=36473, episodic_return=1
# global_step=36504, episodic_return=0.99
# global_step=36527, episodic_return=1
# global_step=36546, episodic_return=1
# global_step=36571, episodic_return=1
# global_step=36579, episodic_return=1
# global_step=36596, episodic_return=1
# global_step=36621, episodic_return=1
# global_step=36646, episodic_return=1
# global_step=36662, episodic_return=1
# global_step=36687, episodic_return=1
# global_step=36702, episodic_return=1
# global_step=36734, episodic_return=0.99
# global_step=36747, episodic_return=1
# global_step=36763, episodic_return=1
# global_step=36791, episodic_return=1
# global_step=36810, episodic_return=1
# global_step=36827, episodic_return=1
# global_step=36842, episodic_return=0.99
# global_step=36856, episodic_return=1
# global_step=36868, episodic_return=1
# global_step=36886, episodic_return=1
# global_step=36903, episodic_return=1
# global_step=36922, episodic_return=1
# global_step=36940, episodic_return=1
# global_step=36955, episodic_return=1
# global_step=36970, episodic_return=1
# global_step=36987, episodic_return=1
# global_step=37018, episodic_return=1
# global_step=37039, episodic_return=1
# global_step=37057, episodic_return=1
# global_step=37078, episodic_return=1
# global_step=37090, episodic_return=1
# global_step=37110, episodic_return=1
# global_step=37124, episodic_return=1
# global_step=37149, episodic_return=1
# global_step=37161, episodic_return=1
# global_step=37196, episodic_return=1
# global_step=37223, episodic_return=1
# global_step=37235, episodic_return=1
# global_step=37248, episodic_return=1
# global_step=37264, episodic_return=1
# global_step=37281, episodic_return=1
# global_step=37302, episodic_return=1
# global_step=37326, episodic_return=1
# global_step=37347, episodic_return=1
# global_step=37367, episodic_return=1
# global_step=37387, episodic_return=1
# global_step=37410, episodic_return=1
# global_step=37423, episodic_return=1
# global_step=37443, episodic_return=0.99
# global_step=37459, episodic_return=1
# global_step=37484, episodic_return=1
# global_step=37499, episodic_return=0.99
# global_step=37520, episodic_return=0.99
# global_step=37542, episodic_return=0.99
# global_step=37563, episodic_return=0.99
# global_step=37583, episodic_return=1
# global_step=37599, episodic_return=1
# global_step=37631, episodic_return=1
# global_step=37650, episodic_return=1
# global_step=37666, episodic_return=1
# global_step=37685, episodic_return=1
# global_step=37699, episodic_return=1
# global_step=37719, episodic_return=1
# global_step=37748, episodic_return=1
# global_step=37762, episodic_return=1
# global_step=37776, episodic_return=1
# global_step=37795, episodic_return=1
# global_step=37818, episodic_return=1
# global_step=37837, episodic_return=1
# global_step=37862, episodic_return=0.99
# global_step=37881, episodic_return=1
# global_step=37900, episodic_return=0.99
# global_step=37926, episodic_return=1
# global_step=37944, episodic_return=0.99
# global_step=37964, episodic_return=1
# global_step=37988, episodic_return=1
# global_step=38000, episodic_return=1
# global_step=38020, episodic_return=1
# global_step=38046, episodic_return=1
# global_step=38072, episodic_return=1
# global_step=38091, episodic_return=1
# global_step=38113, episodic_return=1
# global_step=38128, episodic_return=1
# global_step=38146, episodic_return=1
# global_step=38165, episodic_return=1
# global_step=38184, episodic_return=1
# global_step=38198, episodic_return=1
# global_step=38209, episodic_return=1
# global_step=38225, episodic_return=1
# global_step=38240, episodic_return=1
# global_step=38251, episodic_return=1
# global_step=38268, episodic_return=1
# global_step=38287, episodic_return=1
# global_step=38326, episodic_return=1
# global_step=38362, episodic_return=1
# global_step=38385, episodic_return=1
# global_step=38414, episodic_return=1
# global_step=38425, episodic_return=1
# global_step=38439, episodic_return=1
# global_step=38458, episodic_return=0.96
# global_step=38476, episodic_return=1
# global_step=38491, episodic_return=0.99
# global_step=38501, episodic_return=1
# global_step=38513, episodic_return=1
# global_step=38523, episodic_return=1
# global_step=38544, episodic_return=1
# global_step=38564, episodic_return=1
# global_step=38587, episodic_return=1
# global_step=38608, episodic_return=1
# global_step=38635, episodic_return=1
# global_step=38645, episodic_return=1
# global_step=38670, episodic_return=0.99
# global_step=38684, episodic_return=1
# global_step=38698, episodic_return=1
# global_step=38716, episodic_return=1
# global_step=38743, episodic_return=1
# global_step=38761, episodic_return=1
# global_step=38788, episodic_return=1
# global_step=38805, episodic_return=1
# global_step=38814, episodic_return=1
# global_step=38826, episodic_return=1
# global_step=38842, episodic_return=1
# global_step=38861, episodic_return=1
# global_step=38881, episodic_return=1
# global_step=38894, episodic_return=1
# global_step=38927, episodic_return=1
# global_step=38943, episodic_return=1
# global_step=38958, episodic_return=1
# global_step=38973, episodic_return=1
# global_step=39007, episodic_return=1
# global_step=39028, episodic_return=0.99
# global_step=39046, episodic_return=0.99
# global_step=39058, episodic_return=1
# global_step=39075, episodic_return=1
# global_step=39093, episodic_return=1
# global_step=39107, episodic_return=1
# global_step=39121, episodic_return=1
# global_step=39137, episodic_return=1
# global_step=39155, episodic_return=1
# global_step=39174, episodic_return=0.99
# global_step=39201, episodic_return=1
# global_step=39217, episodic_return=1
# global_step=39228, episodic_return=1
# global_step=39249, episodic_return=1
# global_step=39271, episodic_return=0.99
# global_step=39285, episodic_return=1
# global_step=39296, episodic_return=1
# global_step=39312, episodic_return=1
# global_step=39321, episodic_return=1
# global_step=39332, episodic_return=1
# global_step=39353, episodic_return=1
# global_step=39377, episodic_return=1
# global_step=39395, episodic_return=0.99
# global_step=39409, episodic_return=1
# global_step=39422, episodic_return=1
# global_step=39468, episodic_return=1
# global_step=39487, episodic_return=0.99
# global_step=39505, episodic_return=1
# global_step=39532, episodic_return=0.99
# global_step=39561, episodic_return=1
# global_step=39582, episodic_return=1
# global_step=39591, episodic_return=1
# global_step=39620, episodic_return=1
# global_step=39650, episodic_return=0.99
# global_step=39679, episodic_return=1
# global_step=39694, episodic_return=1
# global_step=39708, episodic_return=1
# global_step=39729, episodic_return=0.99
# global_step=39757, episodic_return=1
# global_step=39774, episodic_return=1
# global_step=39790, episodic_return=1
# global_step=39803, episodic_return=1
# global_step=39837, episodic_return=1
# global_step=39860, episodic_return=1
# global_step=39879, episodic_return=1
# global_step=39901, episodic_return=1
# global_step=39930, episodic_return=1
# global_step=39959, episodic_return=1
# global_step=39979, episodic_return=1
# global_step=40004, episodic_return=1
# global_step=40036, episodic_return=0.99
# global_step=40062, episodic_return=0.99
# global_step=40073, episodic_return=1
# global_step=40088, episodic_return=1
# global_step=40099, episodic_return=1
# global_step=40127, episodic_return=0.99
# global_step=40140, episodic_return=1
# global_step=40149, episodic_return=1
# global_step=40169, episodic_return=1
# global_step=40186, episodic_return=1
# global_step=40213, episodic_return=1
# global_step=40231, episodic_return=1
# global_step=40247, episodic_return=1
# global_step=40264, episodic_return=1
# global_step=40275, episodic_return=1
# global_step=40296, episodic_return=1
# global_step=40330, episodic_return=1
# global_step=40345, episodic_return=1
# global_step=40361, episodic_return=1
# global_step=40376, episodic_return=1
# global_step=40384, episodic_return=1
# global_step=40397, episodic_return=1
# global_step=40410, episodic_return=1
# global_step=40423, episodic_return=0.99
# global_step=40440, episodic_return=1
# global_step=40459, episodic_return=1
# global_step=40491, episodic_return=1
# global_step=40507, episodic_return=1
# global_step=40524, episodic_return=1
# global_step=40557, episodic_return=0.99
# global_step=40604, episodic_return=0.99
# global_step=40642, episodic_return=1
# global_step=40669, episodic_return=1
# global_step=40681, episodic_return=0.99
# global_step=40700, episodic_return=0.99
# global_step=40715, episodic_return=1
# global_step=40733, episodic_return=1
# global_step=40757, episodic_return=1
# global_step=40772, episodic_return=1
# global_step=40781, episodic_return=1
# global_step=40816, episodic_return=1
# global_step=40837, episodic_return=1
# global_step=40856, episodic_return=1
# global_step=40876, episodic_return=1
# global_step=40888, episodic_return=1
# global_step=40898, episodic_return=1
# global_step=40916, episodic_return=1
# global_step=40925, episodic_return=1
# global_step=40934, episodic_return=1
# global_step=40947, episodic_return=1
# global_step=40983, episodic_return=0.99
# global_step=41003, episodic_return=1
# global_step=41025, episodic_return=1
# global_step=41045, episodic_return=1
# global_step=41057, episodic_return=0.99
# global_step=41064, episodic_return=1
# global_step=41081, episodic_return=1
# global_step=41118, episodic_return=1
# global_step=41140, episodic_return=0.99
# global_step=41161, episodic_return=1
# global_step=41192, episodic_return=1
# global_step=41221, episodic_return=1
# global_step=41239, episodic_return=0.99
# global_step=41256, episodic_return=1
# global_step=41268, episodic_return=1
# global_step=41283, episodic_return=1
# global_step=41306, episodic_return=1
# global_step=41326, episodic_return=1
# global_step=41347, episodic_return=1
# global_step=41373, episodic_return=1
# global_step=41392, episodic_return=1
# global_step=41409, episodic_return=1
# global_step=41424, episodic_return=1
# global_step=41446, episodic_return=1
# global_step=41457, episodic_return=1
# global_step=41470, episodic_return=1
# global_step=41489, episodic_return=1
# global_step=41497, episodic_return=1
# global_step=41514, episodic_return=1
# global_step=41532, episodic_return=1
# global_step=41555, episodic_return=1
# global_step=41580, episodic_return=1
# global_step=41592, episodic_return=1
# global_step=41615, episodic_return=1
# global_step=41631, episodic_return=1
# global_step=41656, episodic_return=1
# global_step=41677, episodic_return=1
# global_step=41697, episodic_return=1
# global_step=41710, episodic_return=1
# global_step=41725, episodic_return=1
# global_step=41746, episodic_return=0.99
# global_step=41771, episodic_return=0.99
# global_step=41789, episodic_return=1
# global_step=41799, episodic_return=1
# global_step=41814, episodic_return=1
# global_step=41838, episodic_return=1
# global_step=41873, episodic_return=0.99
# global_step=41893, episodic_return=1
# global_step=41911, episodic_return=0.99
# global_step=41978, episodic_return=1
# global_step=41998, episodic_return=0.98
# global_step=42016, episodic_return=1
# global_step=42024, episodic_return=1
# global_step=42038, episodic_return=1
# global_step=42053, episodic_return=1
# global_step=42062, episodic_return=1
# global_step=42078, episodic_return=1
# global_step=42093, episodic_return=0.99
# global_step=42110, episodic_return=1
# global_step=42127, episodic_return=1
# global_step=42149, episodic_return=1
# global_step=42170, episodic_return=1
# global_step=42184, episodic_return=1
# global_step=42197, episodic_return=1
# global_step=42220, episodic_return=1
# global_step=42236, episodic_return=1
# global_step=42245, episodic_return=1
# global_step=42270, episodic_return=1
# global_step=42277, episodic_return=1
# global_step=42308, episodic_return=1
# global_step=42324, episodic_return=1
# global_step=42340, episodic_return=1
# global_step=42356, episodic_return=1
# global_step=42377, episodic_return=1
# global_step=42409, episodic_return=1
# global_step=42445, episodic_return=1
# global_step=42461, episodic_return=0.99
# global_step=42495, episodic_return=1
# global_step=42509, episodic_return=1
# global_step=42528, episodic_return=0.99
# global_step=42537, episodic_return=1
# global_step=42546, episodic_return=1
# global_step=42570, episodic_return=1
# global_step=42592, episodic_return=1
# global_step=42616, episodic_return=1
# global_step=42656, episodic_return=1
# global_step=42673, episodic_return=1
# global_step=42694, episodic_return=1
# global_step=42703, episodic_return=1
# global_step=42739, episodic_return=1
# global_step=42771, episodic_return=1
# global_step=42782, episodic_return=0.99
# global_step=42793, episodic_return=1
# global_step=42809, episodic_return=1
# global_step=42822, episodic_return=1
# global_step=42848, episodic_return=1
# global_step=42870, episodic_return=0.99
# global_step=42884, episodic_return=1
# global_step=42899, episodic_return=1
# global_step=42913, episodic_return=1
# global_step=42928, episodic_return=1
# global_step=42945, episodic_return=1
# global_step=42958, episodic_return=1
# global_step=42978, episodic_return=1
# global_step=42996, episodic_return=1
# global_step=43010, episodic_return=1
# global_step=43033, episodic_return=1
# global_step=43055, episodic_return=1
# global_step=43073, episodic_return=0.99
# global_step=43096, episodic_return=1
# global_step=43109, episodic_return=1
# global_step=43125, episodic_return=1
# global_step=43137, episodic_return=1
# global_step=43164, episodic_return=1
# global_step=43179, episodic_return=1
# global_step=43197, episodic_return=1
# global_step=43211, episodic_return=1
# global_step=43221, episodic_return=1
# global_step=43244, episodic_return=1
# global_step=43263, episodic_return=1
# global_step=43278, episodic_return=1
# global_step=43292, episodic_return=1
# global_step=43312, episodic_return=1
# global_step=43321, episodic_return=1
# global_step=43339, episodic_return=1
# global_step=43360, episodic_return=1
# global_step=43376, episodic_return=1
# global_step=43393, episodic_return=1
# global_step=43409, episodic_return=1
# global_step=43448, episodic_return=1
# global_step=43460, episodic_return=1
# global_step=43479, episodic_return=1
# global_step=43500, episodic_return=1
# global_step=43511, episodic_return=1
# global_step=43530, episodic_return=1
# global_step=43544, episodic_return=1
# global_step=43565, episodic_return=1
# global_step=43582, episodic_return=1
# global_step=43602, episodic_return=1
# global_step=43619, episodic_return=1
# global_step=43639, episodic_return=1
# global_step=43658, episodic_return=1
# ...
# global_step=58197, episodic_return=1
# global_step=58213, episodic_return=1
# global_step=58229, episodic_return=1
# global_step=58242, episodic_return=1
# global_step=58252, episodic_return=1
# global_step=58271, episodic_return=1
# global_step=58283, episodic_return=1
# global_step=58298, episodic_return=1
# global_step=58306, episodic_return=1
# global_step=58323, episodic_return=1
# global_step=58340, episodic_return=1
# global_step=58355, episodic_return=1
# global_step=58368, episodic_return=1
# global_step=58383, episodic_return=1
# global_step=58405, episodic_return=1
# global_step=58421, episodic_return=1
# global_step=58438, episodic_return=1
# global_step=58446, episodic_return=1
# global_step=58470, episodic_return=0.98
# global_step=58483, episodic_return=1
# global_step=58496, episodic_return=1
# global_step=58518, episodic_return=0.99
# global_step=58525, episodic_return=1
# global_step=58547, episodic_return=0.98
# global_step=58562, episodic_return=1
# global_step=58612, episodic_return=1
# global_step=58626, episodic_return=1
# global_step=58639, episodic_return=1
# global_step=58658, episodic_return=1
# global_step=58671, episodic_return=0.99
# global_step=58684, episodic_return=0.99
# global_step=58697, episodic_return=1
# global_step=58712, episodic_return=0.98
# global_step=58729, episodic_return=1
# global_step=58750, episodic_return=1
# global_step=58770, episodic_return=1
# global_step=58783, episodic_return=1
# global_step=58796, episodic_return=1
# global_step=58808, episodic_return=1
# global_step=58818, episodic_return=1
# global_step=58835, episodic_return=1
# global_step=58848, episodic_return=0.99
# global_step=58871, episodic_return=0.99
# global_step=58901, episodic_return=1
# global_step=58912, episodic_return=1
# global_step=58929, episodic_return=0.99
# global_step=58946, episodic_return=1
# global_step=58958, episodic_return=1
# global_step=58970, episodic_return=1
# global_step=58986, episodic_return=1
# global_step=58999, episodic_return=0.98
# global_step=59014, episodic_return=1
# global_step=59029, episodic_return=1
# global_step=59043, episodic_return=1
# global_step=59058, episodic_return=0.99
# global_step=59099, episodic_return=0.97
# global_step=59113, episodic_return=1
# global_step=59125, episodic_return=1
# global_step=59140, episodic_return=1
# global_step=59153, episodic_return=0.98
# global_step=59169, episodic_return=1
# global_step=59186, episodic_return=1
# global_step=59201, episodic_return=1
# global_step=59214, episodic_return=1
# global_step=59229, episodic_return=1
# global_step=59242, episodic_return=1
# global_step=59253, episodic_return=1
# global_step=59268, episodic_return=0.99
# global_step=59281, episodic_return=1
# global_step=59293, episodic_return=1
# global_step=59311, episodic_return=1
# global_step=59330, episodic_return=1
# global_step=59342, episodic_return=1
# global_step=59352, episodic_return=0.96
# global_step=59368, episodic_return=1
# global_step=59386, episodic_return=1
# global_step=59396, episodic_return=1
# global_step=59408, episodic_return=1
# global_step=59423, episodic_return=0.99
# global_step=59437, episodic_return=1
# global_step=59447, episodic_return=1
# global_step=59461, episodic_return=1
# global_step=59471, episodic_return=0.98
# global_step=59487, episodic_return=1
# global_step=59507, episodic_return=1
# global_step=59521, episodic_return=1
# global_step=59536, episodic_return=1
# global_step=59548, episodic_return=1
# global_step=59562, episodic_return=1
# global_step=59577, episodic_return=1
# global_step=59593, episodic_return=1
# global_step=59606, episodic_return=1
# global_step=59612, episodic_return=1
# global_step=59627, episodic_return=1
# global_step=59643, episodic_return=1
# global_step=59651, episodic_return=1
# global_step=59663, episodic_return=1
# global_step=59674, episodic_return=1
# global_step=59688, episodic_return=1
# global_step=59704, episodic_return=1
# global_step=59719, episodic_return=0.99
# global_step=59742, episodic_return=1
# global_step=59754, episodic_return=1
# global_step=59766, episodic_return=1
# global_step=59782, episodic_return=1
# global_step=59795, episodic_return=0.99
# global_step=59815, episodic_return=0.97
# global_step=59833, episodic_return=1
# global_step=59852, episodic_return=1
# global_step=59865, episodic_return=1
# global_step=59874, episodic_return=1
# global_step=59891, episodic_return=1
# global_step=59904, episodic_return=0.98
# global_step=59916, episodic_return=1
# global_step=59935, episodic_return=0.99
# global_step=59950, episodic_return=1
# global_step=59976, episodic_return=1
# global_step=59989, episodic_return=1
# global_step=60189, episodic_return=0
# global_step=60389, episodic_return=-0.01
# global_step=60589, episodic_return=0
# global_step=60789, episodic_return=-0.01
# global_step=60989, episodic_return=-0.02
# global_step=61189, episodic_return=-0.02
# global_step=61389, episodic_return=0
# global_step=61589, episodic_return=-0.01
# global_step=61789, episodic_return=0
# global_step=61989, episodic_return=0
# global_step=62189, episodic_return=0
# global_step=62389, episodic_return=0
# global_step=62589, episodic_return=-0.01
# global_step=62789, episodic_return=-0.01
# global_step=62989, episodic_return=0
# global_step=63189, episodic_return=0
# global_step=63389, episodic_return=0
# global_step=63589, episodic_return=0
# global_step=63789, episodic_return=0
# global_step=63989, episodic_return=0
# global_step=64189, episodic_return=0
# global_step=64389, episodic_return=-0.01
# global_step=64589, episodic_return=0
# global_step=64789, episodic_return=0
# global_step=64989, episodic_return=0
# global_step=65189, episodic_return=0
# global_step=65389, episodic_return=0
# global_step=65589, episodic_return=-0.01
# global_step=65789, episodic_return=-0.01
# global_step=65989, episodic_return=0
# global_step=66189, episodic_return=0
# global_step=66389, episodic_return=0
# global_step=66589, episodic_return=0
# global_step=66789, episodic_return=0
# global_step=66989, episodic_return=0
# global_step=67189, episodic_return=0
# global_step=67389, episodic_return=0
# global_step=67589, episodic_return=0
# global_step=67789, episodic_return=0
# global_step=67989, episodic_return=0
# global_step=68189, episodic_return=0
# global_step=68389, episodic_return=0
# global_step=68589, episodic_return=0
# global_step=68789, episodic_return=0
# global_step=68989, episodic_return=0
# global_step=69189, episodic_return=0
# global_step=69389, episodic_return=0
# global_step=69589, episodic_return=0
# global_step=69595, episodic_return=1
# global_step=69795, episodic_return=0
# global_step=69995, episodic_return=0
# global_step=70195, episodic_return=-0.01
# global_step=70395, episodic_return=0
# global_step=70595, episodic_return=-0.02
# global_step=70795, episodic_return=0
# global_step=70995, episodic_return=-0.01
# global_step=71195, episodic_return=0
# global_step=71395, episodic_return=-0.01
# global_step=71595, episodic_return=0
# global_step=71795, episodic_return=0
# global_step=71995, episodic_return=0
# global_step=72195, episodic_return=0
# global_step=72395, episodic_return=0
# global_step=72595, episodic_return=0
# global_step=72795, episodic_return=-0.02
# global_step=72995, episodic_return=-0.01
# global_step=73195, episodic_return=-0.01
# global_step=73395, episodic_return=0
# global_step=73595, episodic_return=-0.01
# global_step=73795, episodic_return=0
# global_step=73995, episodic_return=0
# global_step=74195, episodic_return=0
# global_step=74395, episodic_return=-0.08
# global_step=74595, episodic_return=-0.02
# global_step=74795, episodic_return=-0.01
# global_step=74995, episodic_return=-0.01
# global_step=75195, episodic_return=0
# global_step=75395, episodic_return=-0.01
# global_step=75595, episodic_return=-0.03
# global_step=75795, episodic_return=0
# global_step=75995, episodic_return=-0.02
# global_step=76195, episodic_return=0
# global_step=76395, episodic_return=-0.02
# global_step=76595, episodic_return=0
# global_step=76795, episodic_return=0
# global_step=76995, episodic_return=-0.01
# global_step=77195, episodic_return=-0.02
# global_step=77202, episodic_return=1
# global_step=77402, episodic_return=-0.02
# global_step=77602, episodic_return=0
# global_step=77802, episodic_return=0
# global_step=78002, episodic_return=0
# global_step=78202, episodic_return=0
# global_step=78402, episodic_return=0
# global_step=78602, episodic_return=-0.01
# global_step=78802, episodic_return=-0.02
# global_step=79002, episodic_return=-0.01
# global_step=79202, episodic_return=-0.02
# global_step=79402, episodic_return=0
# global_step=79602, episodic_return=-0.01
# global_step=79802, episodic_return=0
# global_step=80002, episodic_return=0
# global_step=80202, episodic_return=0
# global_step=80402, episodic_return=0
# global_step=80602, episodic_return=0
# global_step=80802, episodic_return=-0.060000000000000005
# global_step=81002, episodic_return=-0.01
# global_step=81202, episodic_return=0
# global_step=81402, episodic_return=0
# global_step=81602, episodic_return=0
# global_step=81802, episodic_return=-0.01
# global_step=82002, episodic_return=-0.02
# global_step=82202, episodic_return=0
# global_step=82402, episodic_return=0
# global_step=82602, episodic_return=-0.01
# global_step=82802, episodic_return=0
# global_step=83002, episodic_return=0
# global_step=83202, episodic_return=0
# global_step=83402, episodic_return=-0.04
# global_step=83602, episodic_return=-0.02
# global_step=83802, episodic_return=0
# global_step=84002, episodic_return=0
# global_step=84202, episodic_return=0
# global_step=84402, episodic_return=-0.01
# global_step=84602, episodic_return=0
# global_step=84802, episodic_return=-0.02
# global_step=85002, episodic_return=-0.02
# global_step=85202, episodic_return=0
# global_step=85402, episodic_return=0
# global_step=85602, episodic_return=0
# global_step=85802, episodic_return=-0.03
# global_step=86002, episodic_return=-0.01
# global_step=86202, episodic_return=0
# global_step=86402, episodic_return=0
# global_step=86602, episodic_return=0
# global_step=86802, episodic_return=0
# global_step=87002, episodic_return=0
# global_step=87202, episodic_return=0
# global_step=87402, episodic_return=0
# global_step=87602, episodic_return=0
# global_step=87802, episodic_return=0
# global_step=88002, episodic_return=0
# global_step=88202, episodic_return=-0.02
# global_step=88402, episodic_return=0
# global_step=88602, episodic_return=0
# global_step=88802, episodic_return=0
# global_step=89002, episodic_return=0
# global_step=89202, episodic_return=-0.01
# global_step=89402, episodic_return=-0.03
# global_step=89602, episodic_return=-0.04
# global_step=89802, episodic_return=0
# global_step=90002, episodic_return=0
# global_step=90202, episodic_return=0
# global_step=90402, episodic_return=0
# global_step=90602, episodic_return=0
# global_step=90802, episodic_return=-0.02
# global_step=91002, episodic_return=-0.01
# global_step=91202, episodic_return=0
# global_step=91402, episodic_return=-0.02
# global_step=91602, episodic_return=0
# global_step=91802, episodic_return=0
# global_step=92002, episodic_return=0
# global_step=92202, episodic_return=0
# global_step=92402, episodic_return=0
# global_step=92602, episodic_return=0
# global_step=92802, episodic_return=0
# global_step=93002, episodic_return=0
# global_step=93202, episodic_return=0
# global_step=93402, episodic_return=-0.01
# global_step=93602, episodic_return=0
# global_step=93802, episodic_return=0
# global_step=94002, episodic_return=-0.04
# global_step=94202, episodic_return=0
# global_step=94402, episodic_return=0
# global_step=94602, episodic_return=0
# global_step=94802, episodic_return=0
# global_step=95002, episodic_return=0
# global_step=95202, episodic_return=0
# global_step=95402, episodic_return=0
# global_step=95602, episodic_return=0
# global_step=95802, episodic_return=0
# global_step=96002, episodic_return=-0.01
# global_step=96202, episodic_return=0
# global_step=96402, episodic_return=0
# global_step=96602, episodic_return=0
# global_step=96802, episodic_return=0
# global_step=97002, episodic_return=0
# global_step=97202, episodic_return=0
# global_step=97402, episodic_return=0
# global_step=97602, episodic_return=0
# global_step=97802, episodic_return=0
# global_step=98002, episodic_return=0
# global_step=98202, episodic_return=0
# global_step=98402, episodic_return=0
# global_step=98602, episodic_return=0
# global_step=98802, episodic_return=-0.02
# global_step=99002, episodic_return=0
# global_step=99202, episodic_return=0
# global_step=99402, episodic_return=0
# global_step=99602, episodic_return=0
# global_step=99802, episodic_return=-0.01
# global_step=100002, episodic_return=0
# global_step=100202, episodic_return=0
# global_step=100402, episodic_return=-0.02
# global_step=100602, episodic_return=0
# global_step=100802, episodic_return=-0.03
# global_step=101002, episodic_return=0
# global_step=101202, episodic_return=0
# global_step=101402, episodic_return=0
# global_step=101602, episodic_return=0
# global_step=101802, episodic_return=0
# global_step=102002, episodic_return=0
# global_step=102202, episodic_return=-0.01
# global_step=102402, episodic_return=-0.01
# global_step=102602, episodic_return=0
# global_step=102802, episodic_return=0
# global_step=103002, episodic_return=0
# global_step=103202, episodic_return=-0.01
# global_step=103402, episodic_return=0
# global_step=103602, episodic_return=0
# global_step=103802, episodic_return=0
# global_step=104002, episodic_return=0
# global_step=104202, episodic_return=0
# global_step=104402, episodic_return=0
# global_step=104602, episodic_return=0
# global_step=104802, episodic_return=0
# global_step=105002, episodic_return=0
# global_step=105202, episodic_return=0
# global_step=105402, episodic_return=0
# global_step=105602, episodic_return=0
# global_step=105802, episodic_return=0
# global_step=106002, episodic_return=0
# global_step=106202, episodic_return=-0.01
# global_step=106402, episodic_return=0
# global_step=106602, episodic_return=0
# global_step=106802, episodic_return=-0.01
# global_step=107002, episodic_return=0
# global_step=107202, episodic_return=0
# global_step=107402, episodic_return=0
# global_step=107602, episodic_return=0
# global_step=107802, episodic_return=0
# global_step=108002, episodic_return=0
# global_step=108202, episodic_return=0
# global_step=108402, episodic_return=0
# global_step=108602, episodic_return=0
# global_step=108802, episodic_return=0
# global_step=109002, episodic_return=0
# global_step=109202, episodic_return=0
# global_step=109402, episodic_return=0
# global_step=109602, episodic_return=0
# global_step=109802, episodic_return=0
# global_step=110002, episodic_return=0
# global_step=110202, episodic_return=0
# global_step=110402, episodic_return=0
# global_step=110602, episodic_return=0
# global_step=110802, episodic_return=0
# global_step=111002, episodic_return=0
# global_step=111202, episodic_return=0
# global_step=111402, episodic_return=0
# global_step=111602, episodic_return=-0.01
# global_step=111802, episodic_return=0
# global_step=112002, episodic_return=0
# global_step=112202, episodic_return=-0.01
# global_step=112402, episodic_return=-0.01
# global_step=112602, episodic_return=0
# global_step=112802, episodic_return=0
# global_step=113002, episodic_return=0
# global_step=113202, episodic_return=0
# global_step=113402, episodic_return=0
# global_step=113602, episodic_return=0
# global_step=113802, episodic_return=0
# global_step=114002, episodic_return=0
# global_step=114202, episodic_return=0
# global_step=114402, episodic_return=0
# global_step=114602, episodic_return=0
# global_step=114609, episodic_return=1
# global_step=114809, episodic_return=0
# global_step=115009, episodic_return=0
# global_step=115209, episodic_return=0
# global_step=115409, episodic_return=0
# global_step=115609, episodic_return=0
# global_step=115809, episodic_return=0
# global_step=116009, episodic_return=0
# global_step=116209, episodic_return=0
# global_step=116409, episodic_return=0
# global_step=116609, episodic_return=0
# global_step=116809, episodic_return=0
# global_step=117009, episodic_return=0
# global_step=117209, episodic_return=0
# global_step=117409, episodic_return=0
# global_step=117609, episodic_return=0
# global_step=117809, episodic_return=0
# global_step=118009, episodic_return=0
# global_step=118209, episodic_return=0
# global_step=118409, episodic_return=0
# global_step=118609, episodic_return=0
# global_step=118809, episodic_return=0
# global_step=119009, episodic_return=0
# global_step=119209, episodic_return=0
# global_step=119409, episodic_return=0
# global_step=119609, episodic_return=0
# global_step=119809, episodic_return=0
